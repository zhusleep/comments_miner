# %%
import pandas as pd

# %%
data = pd.read_pickle('result/ner_link_part.pkl')

# %%
data['p_label'] = data['predict'].apply(lambda x:x>0.56)

# %%
data.shape
# Out:
# (531, 6)

# %%
data[data.label!=data.p_label]
# Out:
#                                                   text         pos1  \
# 10   上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不错 适合肤...  (20, 23, A)
# 30               发货很快，活动期间买的，特别合算，面膜纸贴合很好，精华也蛮多，可以用好久了    (5, 6, A)
# 95                         面膜用还挺好的自己 补水效果很好?快递小哥态度也很好?  (14, 15, O)
# 204             几百块钱的产品里给我放个近期在里面  还说都是保质期三四年呢客服态度敷衍了事  (12, 13, O)
# 259                  朋友推荐的这款，第一次使用，很清爽保湿，有一点淡淡的香味，特别好闻  (26, 27, A)
# 266                         正品！ 和在屈臣氏的味道一样～不是很好闻～ 但是正常  (10, 11, A)
# 279       第二次购买了，温和卸妆无负担，卸眼妆都不会感觉刺激，也不干，卸的干净，量大耐用。挺喜欢的    (7, 8, O)
# 303    非常好。第一次买。用起来很好。很白。隔离效果很好。也不壳粉 以后会继续购买 送了赠品 都是正品  (18, 21, A)
# 338        个人干湿混合型，上妆比较滋润，相较其他遮瑕，没有那么强，比较轻薄。持久度还是挺ok的，  (19, 20, A)
# 380                       很香，保湿做好不会有卡粉浮粉现象。就是补妆要勤快些。呵呵    (7, 9, O)
# 416                确认过鼻子，是我喜欢的味道，这个味道很熟悉，但就是说不上来是哪一种感觉  (11, 12, A)
# 469                            性价比高，被好评吸引过来，还有赠品，用用再说。    (6, 7, O)
# 486                  补水效果好，用后脸水润润的，味道清香，易吸收，做活动买的，很划算。  (24, 25, A)
# 492         面膜超级划算，很喜欢**买东西，又便宜又快。购物体验很好！面膜也不错。补水效果不错！  (32, 33, O)
#
#             pos2  label   predict  p_label
# 10   (39, 41, O)      0  0.998630     True
# 30   (12, 15, O)      1  0.438842    False
# 95   (17, 22, A)      1  0.000003    False
# 204  (23, 25, A)      1  0.035893    False
# 259  (29, 32, O)      1  0.000483    False
# 266  (15, 19, O)      1  0.556756    False
# 279   (9, 10, A)      1  0.109984    False
# 303  (26, 28, O)      0  0.922319     True
# 338  (22, 26, O)      1  0.001524    False
# 380  (10, 11, A)      1  0.000217    False
# 416  (18, 20, O)      1  0.004325    False
# 469  (15, 16, A)      0  0.989443     True
# 486  (29, 31, O)      1  0.007296    False
# 492  (35, 38, A)      1  0.000007    False
