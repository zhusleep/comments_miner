# %%
# !ls TRAIN
# Out:
# ¸´Èü²âÊÔ¼¯2019-09-10	 Train_laptop_reviews.csv  复赛测试集2019-09-10.zip
# ¸´ÈüÑµÁ·¼¯2019-09-01	 Train_makeup_labels.csv   复赛训练集2019-09-01.zip
# Train_labels.csv	 Train_makeup_reviews.csv
# Train_laptop_labels.csv  Train_reviews.csv

# %%
import pandas as pd

# %%
train = pd.read_csv('TRAIN/Train_makeup_reviews.csv')
labels = pd.read_csv('TRAIN/Train_makeup_labels.csv')

# %%
labels.shape
# Out:
# (25982, 9)

# %%
# 标注错误
# 纠错逻辑　标注人员将多个很好标注为一个很好，位置错位
labels.loc[6222,'O_start']=14
labels.loc[6222,'O_end']=16
labels.loc[5613,'O_start']=30
labels.loc[5613,'O_end']=32
labels.loc[2488,'O_start']=28
labels.loc[2488,'O_end']=30
labels.loc[2224,'O_start']=18
labels.loc[2224,'O_end']=20
labels.loc[2610,'O_start']=44
labels.loc[2610,'O_end']=46
labels.loc[2146,'O_start']=15
labels.loc[2146,'O_end']=17
labels.loc[1858,'O_start']=38
labels.loc[1858,'O_end']=39
labels.loc[866,'A_start']=26
labels.loc[866,'A_end']=28
labels.loc[2488,'O_start']=5
labels.loc[2488,'O_end']=7
labels.loc[1931,'A_end']=11
labels.loc[1931,'O_end']=14
labels.loc[201,'O_start']=24
labels.loc[201,'O_end']=26
labels.loc[1163,'O_start']=39
labels.loc[1163,'O_end']=41


labels.loc[1699,'Polarities']='负面'
labels.loc[1700,'Polarities']='负面'
labels.loc[1701,'Polarities']='负面'
labels.loc[1679,'Polarities']='负面'
labels.loc[1977,'Polarities']='负面'
labels.loc[2304,'Polarities']='负面'

labels.loc[3440,'AspectTerms']='_'
labels.loc[3440,'Categories']='整体'
labels.loc[1446,'Categories']='整体'
labels.loc[1684,'Categories']='整体'
labels.loc[1748,'Categories']='包装'
labels.loc[2228,'Categories']='尺寸'
# 纠错逻辑　标注人员对性价比的标注应当是价格
labels.loc[1305,'Categories']='价格'
labels.loc[5135,'Categories']='价格'
labels.loc[2853,'Categories']='价格'
labels.loc[4298,'Categories']='功效'

labels.loc[316,'AspectTerms']='_'
train['Reviews'] = train['Reviews'].apply(lambda x:x.replace('增品','赠品'))
# 纠错逻辑　labels[(labels.AspectTerms!='_')&(labels.Categories=='整体')]　目标标注人员对于整体这个类别的aspect都是不标的
labels.loc[858,'Categories']='气味'
labels.loc[1392,'AspectTerms']='_'
labels.loc[1392,'OpinionTerms']='好评'
labels.loc[1392,'O_start']=41
labels.loc[1392,'O_end']=43
labels.loc[1906,'Categories']='包装'
labels.loc[2008,'Categories']='其他'
labels.loc[2689,'Categories']='功效'
labels.loc[3460,'Categories']='功效'
labels.loc[3890,'Categories']='速度'

# %%
labels.loc[4298,:]
# Out:
# id              2077
# AspectTerms     补水效果
# A_start           37
# A_end             41
# OpinionTerms       _
# O_start
# O_end
# Categories        功效
# Polarities        中性
# Name: 4298, dtype: object

# %%
train
# Out:
#           id                                           Reviews
# 0          1                                   看到***~买的，发货速度挺快
# 1          2                              卸妆很干净温和不刺激，用完脸滑滑的，舒服
# 2          3                          买来做水疗用的，比我在实体店买的便宜，用完再来。
# 3          4  这刀片没法用刮不下来，不知道好评是不是刷出来的，想回复问题都不让&hellip;&hellip;
# 4          5                                中午下单下午送到，太快了，支持**。
# 5          6                                   第三次购买，一如既往的好用🌹🌹
# 6          7                                  还没试，试了再来评价，看着很小罐
# 7          8                      味道很不错，以前用过，现在又换回来了，期待一如以往的好用
# 8          9                                 价格实惠，质量好，样子也简单。喜欢
# 9         10                                           暂时用着可以😊
# 10        11                                    这款价格经常变动越来越高了啊
# 11        12                      不知道这是第多少次买这个了，一直用，没有换过1。还行吧。
# 12        13                               物流很快，第一次用这款面膜，希望好用。
# 13        14                 已经是第二次购买，适合自己的皮肤，但是油性皮肤的可能感觉比较滋润。
# 14        15                                      东西有问题，解决不了问题
# 15        16                                       挺好用的，清爽不粘腻。
# 16        17                           这款面膜补水不错，化妆品我用的也是这款，支持?
# 17        18                                        宝贝收到了，用着很好
# 18        19                              不错，今天擦了，朋友说像用了美颜滤镜一样
# 19        20                                    滋润及保湿：比较保湿 不油腻
# 20        21            刚使用了下，真的很好用，之前买过其他家的，这家质量很好，线也不会起球，满意！
# 21        22                           一直都是用的这个牌子的护肤品，补水效果很好呢，
# 22        23                                         效果很好物流很快。
# 23        24                                   效果不错，也不过敏，挺温和的！
# 24        25                                  朋友推荐买的，还没用过，希望好用
# 25        26                               都不能用，简直是拿钱买垃圾，谁买谁上当
# 26        27                    很好用，很滋润，主要是不油腻，防晒效果也很好，下一次买90的
# 27        28                            试用了一下，感觉很好吸收，也不油腻，也很滋润
# 28        29                       差评，第一次经历发错货，我买的赏花兔，给我发的粉底猪脸
# 29        30                                           补水效果看的见
# ...      ...                                               ...
# 13633  13634                                          不油腻 效果未知
# 13634  13635              活动期间挺划算的趁机囤一点，双云代言的要支持一下啊！还没用等用过了在评价
# 13635  13636                     氨基酸洗面奶很好用，泡沫细腻，洗后清爽皮肤不绷紧，很补水。
# 13636  13637                       原本怕用了会过敏，试了几天效果很好，脸上痘痘少了很多。
# 13637  13638                         面膜非常好用，每天一片，这个搞活动真的超级划算啊！
# 13638  13639  以前一直用的是***的，这次换成了***的，这款比***的粘稠些，也挺好用的，也很好推开，好评。
# 13639  13640                                             瓶子太小了
# 13640  13641            整体描述：很好用，控油效果还不错，一天下来也不回特别油，还送了卸妆水，很满意
# 13641  13642                    超级不防水，晕染特别快，就感觉像大熊猫一样，踩雷了，就这样吧
# 13642  13643                                     帮妈妈买的，妈妈觉得很喜欢
# 13643  13644                                      非常的好，以后就买这家。
# 13644  13645                      服务超级棒  物流很快  东西也是正品  这次网购很高兴
# 13645  13646                                         买了N次了，是正品
# 13646  13647                    还是不错的，挺漂亮的盒子，粉扑要是透明的那种就好了，这种吃粉
# 13647  13648                        第二次购买  物美价廉  效果不错挺好的  配送很快
# 13648  13649                                       很好用，很温和值得推荐
# 13649  13650                                   对于毛孔大的人士  会堵塞毛孔
# 13650  13651                                          一直在用，效果好
# 13651  13652                                外壳有点色差，不是很绿，拿来当镜子用
# 13652  13653                       物流很快。第二天早上就到了。还送了面膜。卸妆水。棒棒哒
# 13653  13654   修眉刀片收到了，刀片挺气锋利的，搭配修眉刀更好用，已关注本店，用完再来，满满的一盒必须给好评。
# 13654  13655                                           真的很清爽保湿
# 13655  13656                  感觉不是很好用 也不知道是不是我长期没用气垫的过。但是妆感还可以
# 13656  13657                        凑单买的 麻麻说不错 应该没有什么问题 好用 买买买
# 13657  13658                                  刚收到，很不错哦，包装挺细心的！
# 13658  13659                                我觉得挺好，装旁氏散粉真好哈哈哈哈哈
# 13659  13660                                          不好干的，味道大
# 13660  13661                       感谢客服的耐心，物流超快，虽然还没用，相信效果非常好。
# 13661  13662               之前买的102，这次活动101，还没用，室友买了只101，我感觉还不错
# 13662  13663                                         看着漂亮，粉质不好
#
# [13663 rows x 2 columns]

# %%
labels
# Out:
#           id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 0          1        发货速度       9    13           挺快      13    15         物流
# 1          2          卸妆       0     2          很干净       2     5         功效
# 2          2           _                         温和       5     7       使用体验
# 3          2           _                        不刺激       7    10       使用体验
# 4          2           _                        滑滑的      14    17       使用体验
# 5          2           _                         舒服      18    20       使用体验
# 6          3           _                         便宜      16    18         价格
# 7          4          刀片       1     3          没法用       3     6         其他
# 8          4           _                       刮不下来       6    10         功效
# 9          5           _                        太快了       9    12         物流
# 10         6           _                         好用      11    13         整体
# 11         7           _                         很小      13    15         尺寸
# 12         8          味道       0     2          很不错       2     5         气味
# 13         8           _                         好用      26    28         整体
# 14         9          价格       0     2           实惠       2     4         价格
# 15         9          质量       5     7            好       7     8         整体
# 16         9          样子       9    11           简单      12    14         其他
# 17         9           _                         喜欢      15    17         整体
# 18        10           _                         可以       4     6         整体
# 19        11          价格       2     4        越来越高了       8    13         价格
# 20        12           _                         还行      24    26         整体
# 21        13          物流       0     2           很快       2     4         物流
# 22        14           _                       比较滋润      28    32       使用体验
# 23        15           _                        有问题       2     5         整体
# 24        16           _                       挺好用的       0     4         整体
# 25        16           _                         清爽       5     7       使用体验
# 26        16           _                        不粘腻       7    10       使用体验
# 27        17          补水       4     6           不错       6     8         功效
# 28        18           _                         很好       8    10         整体
# 29        19           _                         不错       0     2         整体
# ...      ...         ...     ...   ...          ...     ...   ...        ...
# 25952  13648          效果      13    15           不错      15    17         功效
# 25953  13648          效果      13    15          挺好的      17    20         功效
# 25954  13648          配送      22    24           很快      24    26         物流
# 25955  13649           _                        很好用       0     3         整体
# 25956  13649           _                        很温和       4     7         整体
# 25957  13650           _                      会堵塞毛孔      10    15       使用体验
# 25958  13651           _                          好       7     8         整体
# 25959  13652          外壳       0     2         有点色差       2     6         包装
# 25960  13652          外壳       0     2         不是很绿       7    11         包装
# 25961  13653          物流       0     2           很快       2     4         物流
# 25962  13653           _                        棒棒哒      24    27         整体
# 25963  13654          刀片       8    10        挺气锋利的      10    15         其他
# 25964  13654           _                         好用      22    24         整体
# 25965  13654           _                         好评      44    46         整体
# 25966  13655           _                        很清爽       2     5       使用体验
# 25967  13655           _                         保湿       5     7         功效
# 25968  13656           _                      不是很好用       2     7         整体
# 25969  13656          妆感      27    29          还可以      29    32       使用体验
# 25970  13657           _                         不错       8    10         整体
# 25971  13658          包装       9    11         挺细心的      11    15         包装
# 25972  13658           _                        很不错       4     7         整体
# 25973  13659           _                         挺好       3     5         整体
# 25974  13659           _                         真好      11    13         整体
# 25975  13660           _                        不好干       0     3       使用体验
# 25976  13660          味道       5     7            大       7     8         气味
# 25977  13661          客服       2     4           耐心       5     7         服务
# 25978  13661          物流       8    10           超快      10    12         物流
# 25979  13662           _                        还不错      32    35         整体
# 25980  13663           _                         漂亮       2     4         整体
# 25981  13663          粉质       5     7           不好       7     9       使用体验
#
#       Polarities
# 0             正面
# 1             正面
# 2             正面
# 3             正面
# 4             正面
# 5             正面
# 6             正面
# 7             负面
# 8             负面
# 9             正面
# 10            正面
# 11            负面
# 12            正面
# 13            正面
# 14            正面
# 15            正面
# 16            正面
# 17            正面
# 18            正面
# 19            负面
# 20            中性
# 21            正面
# 22            正面
# 23            负面
# 24            正面
# 25            正面
# 26            正面
# 27            正面
# 28            正面
# 29            正面
# ...          ...
# 25952         正面
# 25953         正面
# 25954         正面
# 25955         正面
# 25956         正面
# 25957         负面
# 25958         正面
# 25959         负面
# 25960         负面
# 25961         正面
# 25962         正面
# 25963         正面
# 25964         正面
# 25965         正面
# 25966         正面
# 25967         正面
# 25968         负面
# 25969         正面
# 25970         正面
# 25971         正面
# 25972         正面
# 25973         正面
# 25974         正面
# 25975         负面
# 25976         负面
# 25977         正面
# 25978         正面
# 25979         正面
# 25980         正面
# 25981         负面
#
# [25982 rows x 9 columns]

# %%
labels[labels.id==3088]
# Out:
#         id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 5799  3088           _                         不错       0     2         整体
# 5800  3088           _                         持久       5     7         功效
#
#      Polarities
# 5799         正面
# 5800         正面

# %%
train.loc[train.id==3088,'Reviews']
# Out:
# 3087    不错 👌持久
# Name: Reviews, dtype: object

# %%
drop_id = []
for index,row in labels.iterrows():
    if row['AspectTerms']!='_':
        try:
            text = train.loc[row['id']-1,'Reviews'][int(row['A_start']):int(row['A_end'])]
            #print(text)
            assert text==row['AspectTerms']
        except:
            if row['id'] not in drop_id:
                drop_id.append(row['id'])
            print(row['AspectTerms'],text,)
    if row['OpinionTerms']!='_':
        try:
            text = train.loc[row['id']-1,'Reviews'][int(row['O_start']):int(row['O_end'])]
            #print(text)
            assert text==row['OpinionTerms']
        except:
            if row['id'] not in drop_id:
                drop_id.append(row['id'])
            print(row['OpinionTerms'],text,)
# Out:
# 超级好用 级好用哦
# 光滑细腻 滑细腻不
# 不紧绷 紧绷，
# 活动 动很
# 很划算 划算，
# 效果 果应
# 会有 有的
# 天猫直送 **直送
# 赞
# 便宜 宜，
# 完全没有用 全没有用。
# 这么短 么短这
# 这么脆弱 么脆弱😊
# 物超所值 超所值！
# 大爱 爱呀
# 持久 久
# 客服 服人
# 很好 好，
# 客服态度 服态度超
# 超好 好👍
# 聚划算 ***
# 挺好看的 挺好看是
# 很短 短。
# 发货速度 货速度快
# 快 赞
# 胶的味道 味道
# 吸收 快，
# 快 不
# 不油腻 腻，有
# 活动 真优
# 真优惠 惠，早
# 不太喜欢这味道 欢这味道，要放
# 快递 递直
# 挺好的 好的！
# 使用效果 用效果：
# 不错 错的
# 便宜 宜
# 价格 格便
# 便宜 宜每
# 很不错 啊，哈
# 大爱 疆了
# 差评 评
# 很不错 很不错的，
# 很暗 暗哪
# 真棒 棒
# 味道 道淡
# 淡淡的 淡的很
# 味道 道淡
# 很喜欢 喜欢呀
# 留香很持久 香很持久。
# 不错 不错的宝
# 没什么效果 什么效果昂
# 小贵 贵😂
# 很自然 自然的
# 方便携带 便携带。

# %%
drop_id
# Out:
# [206,
#  458,
#  1059,
#  1447,
#  1656,
#  2004,
#  2160,
#  2356,
#  2636,
#  3088,
#  3594,
#  4590,
#  5081,
#  5221,
#  6804,
#  6967,
#  7371,
#  7530,
#  8129,
#  8525,
#  8828,
#  9152,
#  10288,
#  10772,
#  11275,
#  11353,
#  11519,
#  11525,
#  11529,
#  11588,
#  12182,
#  13051,
#  13112]

# %%
# train
train_dict = {}
for index, row in train.iterrows():
    if row['id'] not in train_dict:
        train_dict[row['id']] = row['Reviews']
label_group = labels.groupby(['id','AspectTerms'],as_index=False)['Categories'].count()

# %%
label_group[(label_group.AspectTerms!='_')&(label_group.Categories!=1)].head()
# Out:
#       id AspectTerms  Categories
# 153   98          快递           2
# 244  163          包装           2
# 453  320          赠品           2
# 466  328          香味           2
# 501  354          卸妆           2

# %%
labels[(labels.AspectTerms=='性价比')&(labels.Categories!='价格')]['Categories']='价格'
# Out:
# /home/zhukaihua/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
一般默认整体不标记词汇［'产品','质量','隔离','商品','宝贝'］

# %%
labels[(labels.id==2756)]
# Out:
#         id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 5671  2756          物流       0     2           很快       2     4         物流
# 5672  2756          包装       5     7          很严实       7    10         包装
# 5673  2756          活动      16    18            _                       价格
# 5674  2756           _                        很划算      24    27         价格
# 5675  2756          包装       5     7         没有损坏      11    15         包装
#
#      Polarities
# 5671         正面
# 5672         正面
# 5673         正面
# 5674         正面
# 5675         正面

# %%
# labels[(labels.OpinionTerms=='好评')]

# %%
# 手动去除常见描述，然后对类别严格分类

# %%
labels['OpinionTerms'].value_counts().head()
# Out:
# 不错     444
# 很好     329
# 很好用    206
# _      171
# 还不错    163
# Name: OpinionTerms, dtype: int64

# %%
labels[(labels.OpinionTerms=='很划算')&((labels.AspectTerms=='活动'))]
# Out:
#         id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 226    105          活动       0     2          很划算       2     5         价格
# 440    212          活动       9    11          很划算      12    15         价格
# 1042   499          活动      21    23          很划算      25    28         价格
# 1106   528          活动      10    12          很划算      14    17         价格
# 1150   550          活动       4     6          很划算      11    14         价格
# 1158   553          活动      24    26          很划算      29    32         价格
# 2746  1315          活动      18    20          很划算      22    25         价格
# 4102  1988          活动      15    17          很划算      18    21         价格
# 4790  2316          活动       1     3          很划算       8    11         价格
# 5889  2867          活动       7     9          很划算      14    17         价格
#
#      Polarities
# 226          正面
# 440          正面
# 1042         正面
# 1106         正面
# 1150         正面
# 1158         正面
# 2746         正面
# 4102         正面
# 4790         正面
# 5889         正面

# %%
# todo list
1 AspectTerms OpinionTerms ner task
2 AspectTerms near 2 node re extraction
2 if aspect is None or opinion is None:
        text classification cls concat span extractor
    else:
        pass
    # 类别由 aspect dominate
    # some opinion matters,some do not
# Out:
#   File "<tokenize>", line 6
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
text2dict = train['Reviews'].to_dict()

# %%
# aspect and opinion是否连续
span = {}
for index,row in labels.iterrows():
    if row['id'] not in span:
        span[row['id']] = [] 
    if row['AspectTerms']!='_':
        span[row['id']].append((int(row['A_start']),int(row['A_end'])))
    if row['OpinionTerms']!='_':
        span[row['id']].append((int(row['O_start']),int(row['O_end'])))
for id in span:
    span[id] = sorted(list(set(span[id])),key=lambda x:x[0],reverse=False)

# %%
# 打印它们
c =0
for index,row in labels.iterrows():
    if row['AspectTerms']!='_' and row['OpinionTerms']!='_':
        a = span[int(row['id'])].index((int(row['A_start']),int(row['A_end'])))
        b = span[int(row['id'])].index((int(row['O_start']),int(row['O_end'])))
        if abs(a-b)>1:
            c+=1
    #print(a,b,span[int(row['id'])],row['id'])
            text = text2dict[int(row['id'])-1]
            print(text)
            
            t = []
            for s in span[int(row['id'])]:
                t.append(text[s[0]:s[1]])
            print(t)
            print(text[int(row['A_start']):int(row['A_end'])],text[int(row['O_start']):int(row['O_end'])])
# Out:
# 一直信赖**，发货和送货速度都很快，快递小哥也很好，以后还是**
# ['发货', '送货速度', '很快', '快递小哥', '很好']
# 发货 很快
# 五星好评，快递和服务都好评
# ['五星好评', '快递', '服务', '好评']
# 快递 好评
# 快递点个赞，超级快，质量也是杠杠滴，已经买了两三次了，用起来感觉很不错，棒棒哒
# ['快递', '点个赞', '超级快', '质量', '杠杠滴', '很不错', '棒棒哒']
# 快递 超级快
# 用过一瓶了，又买的，隔离保湿效果好，不干
# ['隔离', '保湿效果', '好', '不干']
# 隔离 好
# **实测款，薄薄一层满满精华素，用了几天，保湿提亮效果不错
# ['满满', '精华素', '保湿', '提亮', '不错']
# 保湿 不错
# 面膜收到了，包装的很好，没有破损！**商城的就是好，快递人员服务态度也很好，满意！
# ['包装', '很好', '没有破损', '快递人员服务态度', '满意']
# 包装 没有破损
# 面膜收到了，包装的很好，没有破损！**商城的就是好，快递人员服务态度也很好，满意！
# ['包装', '很好', '没有破损', '快递人员服务态度', '满意']
# 快递人员服务态度 很好
# 闻起来很好闻，效果用了才知道，应该不错，赠品很好很实在
# ['很好闻', '应该不错', '赠品', '很好', '很实在']
# 赠品 很实在
# 看产品成分选的，面膜也很水不粘稠，价格实惠基础补水护肤很适合，至于修复角质层的效果得等一段时间。
# ['很水', '不粘稠', '价格', '实惠', '补水', '护肤', '很适合', '修复角质层']
# 补水 很适合
# 非常好。第一次买。用起来很好。很白。隔离效果很好。也不壳粉 以后会继续购买 送了赠品 都是正品
# ['非常好', '很好', '很白', '隔离效果', '不壳粉', '赠品', '是正品']
# 隔离效果 很好
# 很香，保湿做好不会有卡粉浮粉现象。就是补妆要勤快些。呵呵
# ['很香', '不会有', '卡粉', '浮粉现象']
# 浮粉现象 不会有
# 面膜不错，水分精华很多，包装差劲，就一个透明带子装，没有包装盒，
# ['不错', '水分', '精华', '很多', '包装', '差劲']
# 水分 很多
# 不错挺好，快递及时专业
# ['不错', '挺好', '快递', '及时', '专业']
# 快递 专业
# 第一次买，遮瑕，保湿效果非常好。下次还买。
# ['遮瑕', '保湿效果', '非常好']
# 遮瑕 非常好
# 刚刚用，还不错，喜欢这颜色和味道，继续使用哦
# ['还不错', '喜欢', '颜色', '味道']
# 味道 喜欢
# 一直用这个牌子 特别的好  快递也很快 给商家还有快递小哥一百个赞
# ['特别的好', '快递', '很快', '商家', '快递小哥', '一百个赞']
# 商家 一百个赞
# 包装好物流快给力
# ['包装', '好', '物流', '快', '给力']
# 物流 给力
# 非常满意 客服小海绵的服务也很好 很耐心
# ['非常满意', '服务', '很好', '很耐心']
# 服务 很耐心
# 同品牌用过其它的很好 这个第一次买  希望不会失望 物流服务又好又快
# ['很好', '物流服务', '好', '快']
# 物流服务 快
# 效果一点不好。洗不净。洗了脸上会比较油。不知道那么多好评哪里来的。欺骗消费者
# ['效果', '一点不好', '洗不净', '比较油']
# 效果 洗不净
# 帮朋友代拍的哦，产品好不好不知道，不过快递大哥人很好哦，朋友再三嘱咐给快递大哥个好评哈哈
# ['快递大哥', '人很好', '好评']
# 快递大哥 好评
# 很好用，买了很多，补水很好用，便宜优惠
# ['很好用，买了很多，补水很好用', '很好用', '补水', '便宜', '优惠']
# 补水 很好用，买了很多，补水很好用
# 商品是正品哦，质量棒棒哒，**的服务跟物流一样棒哦
# ['是正品', '质量', '棒棒哒', '服务', '物流', '棒']
# 服务 棒
# 首先不得不说99元买还有两个替换装很划算，其次今天试用了，味道很好闻，很自然。
# ['很划算', '味道', '很好闻', '很自然']
# 味道 很自然
# 清洁能力：泡沫适中，非常舒适，对黑头有一定的清洁作用
# ['清洁能力', '泡沫', '适中', '非常舒适', '有一定的']
# 清洁能力 有一定的
# 一直信赖**，还不错，希望价格多多促销，多多优惠
# ['还不错', '价格', '多多促销', '多多优惠']
# 价格 多多优惠
# 持妆和控油效果都不错，遮暇一般般
# ['持妆', '控油效果', '不错', '遮暇', '一般般']
# 持妆 不错
# 味道不是很喜欢，感觉怪怪的
# ['味道', '不是很喜欢', '怪怪的']
# 味道 怪怪的
# 还不错，遮瑕提亮效果不错，就是稍有点干，皮肤不好的时候会起皮。
# ['还不错', '遮瑕', '提亮效果', '不错', '有点干', '起皮']
# 遮瑕 不错
# 价位经济实惠，这款面膜用着挺好的，挺补水的
# ['价位', '经济', '实惠', '挺好的', '挺补水']
# 价位 实惠
# 一直用这款，保湿补水效果不错
# ['保湿', '补水效果', '不错']
# 保湿 不错
# 已多次购买，品质好，服务好，开票也快！
# ['品质', '服务', '好', '开票', '快']
# 品质 好
# 保湿锁水效果真的很好，趁着还有活动，又下了一单，多存点
# ['保湿', '锁水效果', '很好', '活动']
# 保湿 很好
# 不错.比在超市和店里买划算.卖家和快递服务都不错给五星好评
# ['划算', '卖家', '快递服务', '不错', '五星好评']
# 卖家 不错
# 贴合度：很好很满意。
# ['贴合度', '很好', '很满意']
# 贴合度 很满意
# 商品是正品哦，很补水的哦，**的服务跟物流棒棒哒
# ['是正品', '很补水', '服务', '物流', '棒棒哒']
# 服务 棒棒哒
# 看测评入的，味道挺淡蛮好闻，涂上去还是觉得有点黏黏的，挺小只方便携带~好用的话会回购~
# ['味道', '挺淡', '蛮好闻', '有点黏黏', '挺小只']
# 味道 蛮好闻
# 到货快，好用，补水隔离效果好，价格实惠，很划算很喜欢
# ['到货', '快', '好用', '补水', '隔离效果', '好', '价格', '实惠', '很划算', '很喜欢']
# 补水 好
# 防晒隔离效果不错，涂上后肤色显白又不夸张，用完下次还购买
# ['防晒', '隔离效果', '不错', '显白']
# 防晒 不错
# 上妆效果：不错，很自然。
# ['上妆效果', '不错', '很自然']
# 上妆效果 很自然
# 个人情况：混合性肌肤 整体描述：还行 滋润及保湿：保湿感觉差一些，有点干 吸收情况：属亚光，吸收还好
# ['还行', '保湿', '差一些', '有点干', '吸收', '还好']
# 保湿 有点干
# 很好用的面膜，补水保湿效果好，精华多，比较服帖，薄薄的，很舒服，值得购买！
# ['很好用', '补水', '保湿效果', '好', '精华', '多', '比较服帖', '薄薄的', '很舒服']
# 补水 好
# 节日做活动便宜了很多，很好用补水保湿效果很好，很满足。
# ['活动', '便宜', '很好用', '补水', '保湿效果', '很好', '很满足']
# 补水 很好
# 我的皮肤是敏感皮肤，用过之后再来评价的，保湿美白效果很好，关键是不过敏，还回来回购的。五星好评。
# ['保湿', '美白效果', '很好', '不过敏', '五星好评']
# 保湿 很好
# 用了一段时间才来评价的，洗面奶很好用，泡沫丰富、细腻，好
# ['很好用', '泡沫', '丰富', '细腻']
# 泡沫 细腻
# 还不错，有两个替换装味道香，但不刺鼻，可能有点儿掉妆
# ['还不错', '味道', '香', '不刺鼻', '有点儿掉妆']
# 味道 不刺鼻
# 按压设计很有新意很方便。
# ['按压设计', '很有新意', '很方便']
# 按压设计 很方便
# 很好的宝贝，非常喜欢，物流也快，服务很好，赞一下
# ['很好', '非常喜欢', '物流', '快', '服务', '赞一下']
# 服务 很好
# 今天才开始用，很好用，补水渗透性很强
# ['很好用', '补水', '渗透性', '很强']
# 补水 很强
# 靠谱实在的赠品！
# ['靠谱', '实在', '赠品']
# 赠品 靠谱
# 好用 美白隔离效果很好 肤色暗黄推荐使用
# ['好用', '美白', '隔离效果', '很好']
# 美白 很好
# 支持**，东西很好，很实惠，配送服务态度很好。
# ['很好', '很实惠', '配送服务态度']
# 配送服务态度 很好
# 一直信赖的东东，补水保湿效果特别好。
# ['补水', '保湿效果', '特别好']
# 补水 特别好
# 第一次使用隔离霜感觉美白效果和隔离效果都很不错。
# ['美白效果', '隔离效果', '很不错']
# 美白效果 很不错
# 效果不错哦，而且不伤皮肤，不觉得油腻，卖家服务好，性价比不错哦！
# ['不错', '不伤皮肤', '不觉得油腻', '卖家服务', '好', '性价比']
# 性价比 不错
# 很好用，很喜欢，2个换用，很喜欢，物有所值，包装和快递都好，下次再买
# ['很好用', '很喜欢', '物有所值', '包装', '快递', '好']
# 包装 好
# 清洁能力：泡沫很多，一搓就有，洗的挺干净的，味道也好闻，很温和
# ['清洁能力', '泡沫', '很多', '挺干净的', '味道', '好闻', '很温和']
# 清洁能力 挺干净的
# 比自己皮肤颜色稍微白一点，还是比较自然的，一点点可以用全脸
# ['颜色', '稍微白一点', '比较自然']
# 颜色 比较自然
# 味道很清新自然
# ['味道', '很清新', '自然']
# 味道 自然
# 第二次购买了，补水保湿的效果不错，打算坚持使用，希望脸上皮肤能有所改善
# ['补水', '保湿', '不错']
# 补水 不错
# 物流很快，包装很严实，没有损坏。活动的时候买的，很划算。第一次买，期待效果。
# ['物流', '很快', '包装', '很严实', '没有损坏', '活动', '很划算']
# 包装 没有损坏
# 第二次购买  物美价廉  效果不错挺好的  配送很快
# ['物美价廉', '效果', '不错', '挺好的', '配送', '很快']
# 效果 挺好的
# 价格便宜实惠东西不错，正品下次再来，包装也好，有档次
# ['价格', '便宜', '实惠', '不错', '正品', '包装', '好', '有档次']
# 价格 实惠
# 价格便宜实惠东西不错，正品下次再来，包装也好，有档次
# ['价格', '便宜', '实惠', '不错', '正品', '包装', '好', '有档次']
# 包装 有档次
# 粉质细 上妆轻薄透亮 紫色提亮肤色不夸张 物美价廉 会回购喜欢 要上加上防�就更好了方便一瓶搞定
# ['粉质', '细', '上妆', '轻薄', '透亮', '提亮肤色', '不夸张', '物美价廉', '喜欢']
# 上妆 透亮
# 隔离霜味道很好闻。是我喜欢的味道，就是挤出来的时候一直往外出，止不住
# ['味道', '很好闻', '喜欢']
# 味道 喜欢
# 气味重不好闻，持久度也不好，到中午脸色就蜡黄了
# ['气味', '重', '不好闻', '持久度', '不好']
# 气味 不好闻
# 包装完整没有破损卖家服务态度好有问必答，多次购买还会再来
# ['包装', '完整', '没有破损', '卖家服务态度', '好']
# 包装 没有破损
# 不敢相信这么便宜的面膜一点不比八块十块的差。面膜纸丝薄服帖我很喜欢，补水用也不会心疼。回回购
# ['这么便宜', '面膜纸', '丝薄', '服帖', '很喜欢']
# 面膜纸 服帖
# 发货速度和配送服务还是一流的
# ['发货速度', '配送服务', '一流的']
# 发货速度 一流的

# %%
c
# Out:
# 70

# %%
for index,row in train.iterrows():
    if '物流很快，包装很严实' in row['Reviews']:
        print(row['id'],row['Reviews'])
# Out:
# 2756 物流很快，包装很严实，没有损坏。活动的时候买的，很划算。第一次买，期待效果。

# %%
labels[labels.id==2316]
# Out:
#         id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 4790  2316          活动       1     3          很划算       8    11         价格
#
#      Polarities
# 4790         正面

# %%
train[train.id==2316]
# Out:
#         id       Reviews
# 2315  2316  搞活动的时候买的很划算！

# %%
train[train.id==77]
# Out:
#     id                           Reviews
# 76  77  一直信赖**，发货和送货速度都很快，快递小哥也很好，以后还是**

# %%
1724/6277
# Out:
# 0.27465349689342045

# %%
labels.apply(lambda x:x.AspectTerms!='_' and x.OpinionTerms!='_',axis=1).sum()
# Out:
# 1724

# %%
labels['AspectTerms'].value_counts()
# Out:
# _         4735
# 物流         196
# 价格         140
# 包装         134
# 味道         128
# 活动          90
# 补水效果        75
# 快递          69
# 赠品          52
# 保湿效果        39
# 速度          37
# 补水          32
# 香味          30
# 服务          30
# 泡沫          26
# 性价比         25
# 快递小哥        23
# 送货          22
# 效果          22
# 颜色          21
# 精华          20
# 发货          19
# 精华液         17
# 清洁能力        17
# 遮瑕效果        17
# 保湿          16
# 客服          15
# 卸妆          14
# 服务态度        14
# 送货速度        14
#           ...
# 面积           1
# 遮瑕的效果        1
# 美白作用         1
# 降价           1
# 外表           1
# 清香味          1
# 精华液量         1
# 瓶子塑料         1
# 天猫直送         1
# 开票           1
# 修饰肤色         1
# 客服服务         1
# 外包装          1
# 物流小哥服务       1
# 贴合           1
# 卸妆力          1
# 浮粉           1
# 增白效果         1
# 起泡量          1
# 时间           1
# 价            1
# 客服服务态度       1
# 精华水          1
# 香精           1
# 洁肤           1
# 粉底           1
# 小包装          1
# 问道           1
# 售后           1
# 清香           1
# Name: AspectTerms, Length: 257, dtype: int64
