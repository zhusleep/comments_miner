# %%
import pandas as pd

# %%
polarity = pd.read_pickle('result/final_polarity_old.pkl')

# %%
# polarity_old = pd.read_pickle('result/final_polarity_old.pkl')

# %%
polarity['predict_polarity'].value_counts()
# Out:
# 正面    9119
# 负面    2228
# 中性      79
# Name: predict_polarity, dtype: int64

# %%
# polarity_old['predict_polarity'].value_counts()

# %%
polarity.sort_values('id')
# Out:
#                                                     text                pos1  \
# 9501                           画质清晰，网速很快，吃鸡不卡，真的不错。携带方便。                None
# 9149                           画质清晰，网速很快，吃鸡不卡，真的不错。携带方便。     (20, 21, A, 外观)
# 8591                           画质清晰，网速很快，吃鸡不卡，真的不错。携带方便。   (10, 11, A, 使用场景)
# 4505                           画质清晰，网速很快，吃鸡不卡，真的不错。携带方便。    (5, 6, A, 硬件&性能)
# 1991                           画质清晰，网速很快，吃鸡不卡，真的不错。携带方便。    (0, 1, A, 硬件&性能)
# 3065                                       物流速度很棒呦，包装也很好       (8, 9, A, 包装)
# 1541                                       物流速度很棒呦，包装也很好       (0, 3, A, 物流)
# 5347                         电脑挺好看的，就是有点慢，还有点卡，没有想象中那么好，                None
# 4383                         电脑挺好看的，就是有点慢，还有点卡，没有想象中那么好，                None
# 4578                         电脑挺好看的，就是有点慢，还有点卡，没有想象中那么好，                None
# 11218                        电脑挺好看的，就是有点慢，还有点卡，没有想象中那么好，                None
# 10031                   反正娃最喜欢吃鸡，玩这游戏不卡，目前已经用了好几天，总体还不错。    (9, 12, A, 使用场景)
# 1422                    反正娃最喜欢吃鸡，玩这游戏不卡，目前已经用了好几天，总体还不错。     (26, 27, A, 整体)
# 1565                     宝贝收到了，非常惊喜，外观好看，开机速度快，运行流畅，五星好评     (11, 12, A, 外观)
# 27                       宝贝收到了，非常惊喜，外观好看，开机速度快，运行流畅，五星好评  (22, 23, A, 硬件&性能)
# 1748                     宝贝收到了，非常惊喜，外观好看，开机速度快，运行流畅，五星好评                None
# 2843                     宝贝收到了，非常惊喜，外观好看，开机速度快，运行流畅，五星好评                None
# 6233                     宝贝收到了，非常惊喜，外观好看，开机速度快，运行流畅，五星好评  (16, 19, A, 硬件&性能)
# 8133                包装特别严实，外观设计有档次。用起来特别流畅，按键灵活。这个价格真心不错     (30, 31, A, 价格)
# 10864               包装特别严实，外观设计有档次。用起来特别流畅，按键灵活。这个价格真心不错      (7, 10, A, 外观)
# 10041               包装特别严实，外观设计有档次。用起来特别流畅，按键灵活。这个价格真心不错                None
# 7360                包装特别严实，外观设计有档次。用起来特别流畅，按键灵活。这个价格真心不错  (23, 24, A, 硬件&性能)
# 9865                包装特别严实，外观设计有档次。用起来特别流畅，按键灵活。这个价格真心不错       (0, 1, A, 包装)
# 11380                放暑假了，买来送孩子的礼物，正好学习也用得上。孩子很喜欢，说反应挺快。  (30, 31, A, 硬件&性能)
# 4374                 放暑假了，买来送孩子的礼物，正好学习也用得上。孩子很喜欢，说反应挺快。                None
# 11110                放暑假了，买来送孩子的礼物，正好学习也用得上。孩子很喜欢，说反应挺快。   (16, 17, A, 使用场景)
# 10153               非常好 包裹很严实 比我想象中的还要好 用了一段时间来评价的 我太喜欢了       (4, 5, A, 包装)
# 3098                非常好 包裹很严实 比我想象中的还要好 用了一段时间来评价的 我太喜欢了                None
# 10529               非常好 包裹很严实 比我想象中的还要好 用了一段时间来评价的 我太喜欢了                None
# 329        笔记本电脑开机快，运行流畅，玩大游戏一点不卡顿，质量很好，非常满意，有需要还会回购的五星。   (14, 17, A, 使用场景)
# ...                                                  ...                 ...
# 4904   送货和包装没有问题！风扇声音有点大，但可以接收，显卡弱！拖动有划痕，适配器发热，电脑散热不好...       (3, 4, A, 包装)
# 2593   送货和包装没有问题！风扇声音有点大，但可以接收，显卡弱！拖动有划痕，适配器发热，电脑散热不好...  (24, 25, A, 硬件&性能)
# 2430               拿回来打一看，就跟新的一样，现在玩游不怕卡了，网速超快了，不错，挺满意的。  (23, 24, A, 硬件&性能)
# 11135              拿回来打一看，就跟新的一样，现在玩游不怕卡了，网速超快了，不错，挺满意的。                None
# 2034               拿回来打一看，就跟新的一样，现在玩游不怕卡了，网速超快了，不错，挺满意的。                None
# 7547               拿回来打一看，就跟新的一样，现在玩游不怕卡了，网速超快了，不错，挺满意的。   (16, 17, A, 使用场景)
# 5230       物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿  (38, 39, A, 硬件&性能)
# 1675       物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿  (18, 19, A, 硬件&性能)
# 10296      物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿                None
# 6071       物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿       (5, 8, A, 服务)
# 8516       物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿       (0, 1, A, 物流)
# 3993       物流很快，卖家态度很好， 显卡效果：画面清晰 外观材质：外观满意 电脑性能：运行流畅无卡顿     (28, 29, A, 外观)
# 9088                   满意，颜值高，到货试玩了一下，画质也很高清，运行也很流畅，很满意，       (3, 4, A, 外观)
# 4970                   满意，颜值高，到货试玩了一下，画质也很高清，运行也很流畅，很满意，                None
# 8165                   满意，颜值高，到货试玩了一下，画质也很高清，运行也很流畅，很满意，  (22, 23, A, 硬件&性能)
# 3769                   满意，颜值高，到货试玩了一下，画质也很高清，运行也很流畅，很满意，  (15, 16, A, 硬件&性能)
# 6398                   满意，颜值高，到货试玩了一下，画质也很高清，运行也很流畅，很满意，                None
# 4329                                       电脑用的很溜！愉快的购物！                None
# 9557                                       可以，就是没有u** 接口                None
# 684                                        可以，就是没有u** 接口                None
# 3664                                       电脑运行流畅，材质精致好看       (7, 8, A, 外观)
# 2474                                       电脑运行流畅，材质精致好看    (2, 3, A, 硬件&性能)
# 7425                   白起服务员专业到位，非常满意，下次还会介绍朋友购买&hellip;       (2, 4, A, 服务)
# 11180                  白起服务员专业到位，非常满意，下次还会介绍朋友购买&hellip;                None
# 2128                               这款笔记本还不错，物美价廉，我办公家用正好                None
# 5330                               这款笔记本还不错，物美价廉，我办公家用正好   (15, 16, A, 使用场景)
# 9185                               这款笔记本还不错，物美价廉，我办公家用正好                None
# 10317                             收到货，真心喜欢，不卡机，速度点，赞赞赞赞赞                None
# 8609                              收到货，真心喜欢，不卡机，速度点，赞赞赞赞赞  (13, 14, A, 硬件&性能)
# 4112                              收到货，真心喜欢，不卡机，速度点，赞赞赞赞赞                None
#
#                      pos2 predict_polarity predict_cate    id
# 9501      (15, 18, O, 整体)               正面           整体     0
# 9149      (22, 23, O, 外观)               正面           外观     0
# 8591    (12, 13, O, 使用场景)               正面         使用场景     0
# 4505     (7, 8, O, 硬件&性能)               正面        硬件&性能     0
# 1991     (2, 3, O, 硬件&性能)               正面        硬件&性能     0
# 3065      (11, 12, O, 包装)               正面           包装     1
# 1541        (4, 5, O, 物流)               正面           物流     1
# 5347        (2, 5, O, 外观)               正面           外观     2
# 4383   (14, 16, O, 硬件&性能)               负面        硬件&性能     2
# 4578      (18, 25, O, 整体)               正面           整体     2
# 11218   (9, 11, O, 硬件&性能)               负面        硬件&性能     2
# 10031   (13, 14, O, 使用场景)               正面         使用场景     3
# 1422      (28, 30, O, 整体)               正面           整体     3
# 1565      (13, 14, O, 外观)               正面           外观     4
# 27     (24, 25, O, 硬件&性能)               正面        硬件&性能     4
# 1748      (27, 30, O, 整体)               正面           整体     4
# 2843        (6, 9, O, 整体)               正面           整体     4
# 6233   (20, 20, O, 硬件&性能)               正面        硬件&性能     4
# 8133      (32, 35, O, 价格)               正面           价格     5
# 10864     (11, 13, O, 外观)               正面           外观     5
# 10041  (18, 21, O, 硬件&性能)               正面        硬件&性能     5
# 7360   (25, 26, O, 硬件&性能)               正面        硬件&性能     5
# 9865        (2, 5, O, 包装)               正面           包装     5
# 11380  (32, 33, O, 硬件&性能)               正面        硬件&性能     6
# 4374      (25, 27, O, 整体)               正面           整体     6
# 11110   (19, 21, O, 使用场景)               正面         使用场景     6
# 10153       (6, 8, O, 包装)               正面           包装     7
# 3098      (32, 35, O, 整体)               正面           整体     7
# 10529       (0, 2, O, 整体)               正面           整体     7
# 329     (18, 22, O, 使用场景)               正面         使用场景     8
# ...                   ...              ...          ...   ...
# 4904                 None               负面           包装  3901
# 2593   (26, 26, O, 硬件&性能)               负面        硬件&性能  3901
# 2430   (25, 26, O, 硬件&性能)               正面        硬件&性能  3902
# 11135     (32, 35, O, 整体)               正面           整体  3902
# 2034      (29, 30, O, 整体)               正面           整体  3902
# 7547    (18, 20, O, 使用场景)               正面         使用场景  3902
# 5230   (40, 41, O, 硬件&性能)               正面        硬件&性能  3903
# 1675   (20, 21, O, 硬件&性能)               正面        硬件&性能  3903
# 10296  (42, 44, O, 硬件&性能)               正面        硬件&性能  3903
# 6071       (9, 10, O, 服务)               正面           服务  3903
# 8516        (2, 3, O, 物流)               正面           物流  3903
# 3993      (30, 31, O, 外观)               正面           外观  3903
# 9088        (5, 5, O, 外观)               正面           外观  3904
# 4970        (0, 1, O, 整体)               正面           整体  3904
# 8165   (25, 27, O, 硬件&性能)               正面        硬件&性能  3904
# 3769   (18, 20, O, 硬件&性能)               正面        硬件&性能  3904
# 6398      (29, 31, O, 整体)               正面           整体  3904
# 4329        (4, 5, O, 整体)               正面           整体  3905
# 9557    (5, 12, O, 硬件&性能)               负面        硬件&性能  3906
# 684         (0, 1, O, 整体)               正面           整体  3906
# 3664       (9, 12, O, 外观)               正面           外观  3907
# 2474     (4, 5, O, 硬件&性能)               正面        硬件&性能  3907
# 7425        (5, 8, O, 服务)               正面           服务  3908
# 11180     (10, 13, O, 整体)               正面           整体  3908
# 2128        (5, 7, O, 整体)               正面           整体  3909
# 5330    (19, 20, O, 使用场景)               正面         使用场景  3909
# 9185       (9, 12, O, 价格)               正面           价格  3909
# 10317       (4, 7, O, 整体)               正面           整体  3910
# 8609   (15, 15, O, 硬件&性能)               正面        硬件&性能  3910
# 4112    (9, 11, O, 硬件&性能)               正面        硬件&性能  3910
#
# [11426 rows x 6 columns]

# %%
polarity['id'].describe()
# Out:
# count    11426.000000
# mean      1957.425171
# std       1131.649366
# min          0.000000
# 25%        973.250000
# 50%       1966.000000
# 75%       2938.000000
# max       3910.000000
# Name: id, dtype: float64

# %%
polarity['id'] = polarity['id']+1

# %%
# cate = pd.read_pickle('result/final_cate.pkl')

# %%
cate=polarity

# %%
def extract_text(s,pos):
    if pos is None:
        return '_'
    else:
        return s[pos[0]:pos[1]+1] 
        
cate['aspect'] = cate.apply(lambda x:extract_text(x.text,x.pos1),axis=1)
cate['opinion'] = cate.apply(lambda x:extract_text(x.text,x.pos2),axis=1)

# %%
cate.head()
# Out:
#                                   text               pos1               pos2  \
# 0              宝贝已收到，玩游戏很流畅，款式很时尚，很满意！    (13, 14, A, 外观)    (15, 17, O, 外观)
# 1                  电脑高配，轻巧。运行速度快。使用很方便               None  (16, 18, O, 使用场景)
# 2             显卡效果：画面效果很好 电脑性能：玩游戏很流畅   (17, 19, A, 使用场景)  (20, 22, O, 使用场景)
# 3  电脑收到了，质量很好，很薄，上网很快，玩游戏很通畅，一点都不卡，满意。               None    (32, 33, O, 整体)
# 4                          不卡，很好可以完美吃鸡               None   (0, 1, O, 硬件&性能)
#
#   predict_polarity predict_cate    id aspect opinion
# 0               正面           外观  2003     款式     很时尚
# 1               正面         使用场景  2642      _     很方便
# 2               正面         使用场景  2746    玩游戏     很流畅
# 3               正面           整体  1873      _      满意
# 4               正面        硬件&性能  2991      _      不卡

# %%
complement = []
for i in range(1,3912):
    if i not in cate['id'].unique():
        print(i)
        complement.append([i,'_','_','_','_'])
complement = pd.DataFrame(complement,columns=['id','aspect','opinion','predict_cate','predict_polarity'])
# Out:
# 25
# 67
# 68
# 69
# 228
# 301
# 446
# 448
# 488
# 576
# 994
# 1030
# 1040
# 1077
# 1219
# 1278
# 1335
# 1374
# 1428
# 1441
# 1442
# 1452
# 1686
# 1708
# 1710
# 1734
# 1772
# 1834
# 1846
# 1884
# 1890
# 1934
# 1964
# 2044
# 2059
# 2135
# 2227
# 2232
# 2306
# 2332
# 2409
# 2485
# 2534
# 2739
# 2785
# 2798
# 2842
# 2910
# 2934
# 3089
# 3094
# 3115
# 3128
# 3202
# 3383
# 3435
# 3566
# 3571
# 3748
# 3814

# %%
submit = cate[['id','aspect','opinion','predict_cate','predict_polarity']]
submit = submit.append(complement)

# %%
submit = submit.sort_values(by='id')

# %%
submit
# Out:
#          id aspect   opinion predict_cate predict_polarity
# 9149      1     携带        方便           外观               正面
# 1991      1     画质        清晰        硬件&性能               正面
# 4505      1     网速        很快        硬件&性能               正面
# 8591      1     吃鸡        不卡         使用场景               正面
# 9501      1      _      真的不错           整体               正面
# 1541      2   物流速度        很棒           物流               正面
# 3065      2     包装        很好           包装               正面
# 4578      3      _  没有想象中那么好           整体               正面
# 4383      3      _       有点卡        硬件&性能               负面
# 5347      3      _      挺好看的           外观               正面
# 11218     3      _       有点慢        硬件&性能               负面
# 10031     4   玩这游戏        不卡         使用场景               正面
# 1422      4     总体       还不错           整体               正面
# 6233      5   开机速度         快        硬件&性能               正面
# 27        5     运行        流畅        硬件&性能               正面
# 2843      5      _      非常惊喜           整体               正面
# 1748      5      _      五星好评           整体               正面
# 1565      5     外观        好看           外观               正面
# 8133      6     价格      真心不错           价格               正面
# 10041     6      _      特别流畅        硬件&性能               正面
# 10864     6   外观设计       有档次           外观               正面
# 9865      6     包装      特别严实           包装               正面
# 7360      6     按键        灵活        硬件&性能               正面
# 11110     7     学习       用得上         使用场景               正面
# 11380     7     反应        挺快        硬件&性能               正面
# 4374      7      _       很喜欢           整体               正面
# 3098      8      _      太喜欢了           整体               正面
# 10153     8     包裹       很严实           包装               正面
# 10529     8      _       非常好           整体               正面
# 9127      9     运行        流畅        硬件&性能               正面
# ...     ...    ...       ...          ...              ...
# 9318   3902   风扇声音       有点大        硬件&性能               负面
# 657    3902     温度        稍高        硬件&性能               负面
# 2430   3903     网速        超快        硬件&性能               正面
# 2034   3903      _        不错           整体               正面
# 11135  3903      _      挺满意的           整体               正面
# 7547   3903     玩游       不怕卡         使用场景               正面
# 6071   3904   卖家态度        很好           服务               正面
# 8516   3904     物流        很快           物流               正面
# 1675   3904     画面        清晰        硬件&性能               正面
# 10296  3904      _       无卡顿        硬件&性能               正面
# 5230   3904     运行        流畅        硬件&性能               正面
# 3993   3904     外观        满意           外观               正面
# 4970   3905      _        满意           整体               正面
# 8165   3905     运行       很流畅        硬件&性能               正面
# 9088   3905     颜值         高           外观               正面
# 6398   3905      _       很满意           整体               正面
# 3769   3905     画质       很高清        硬件&性能               正面
# 4329   3906      _        很溜           整体               正面
# 684    3907      _        可以           整体               正面
# 9557   3907      _  没有u** 接口        硬件&性能               负面
# 3664   3908     材质      精致好看           外观               正面
# 2474   3908     运行        流畅        硬件&性能               正面
# 7425   3909    服务员      专业到位           服务               正面
# 11180  3909      _      非常满意           整体               正面
# 5330   3910     办公        正好         使用场景               正面
# 9185   3910      _      物美价廉           价格               正面
# 2128   3910      _       还不错           整体               正面
# 8609   3911     速度         点        硬件&性能               正面
# 10317  3911      _      真心喜欢           整体               正面
# 4112   3911      _       不卡机        硬件&性能               正面
#
# [11486 rows x 5 columns]

# %%
submit.to_csv('submit/Result_0918.csv',header=None,index=False)

# %%
submit['predict_polarity'].value_counts()
# Out:
# 正面    9119
# 负面    2228
# 中性      79
# _       60
# Name: predict_polarity, dtype: int64

# %%
submit.shape
# Out:
# (11486, 5)

# %%
submit[(submit.aspect!='_')&(submit.predict_cate=='整体')]
# Out:
#          id aspect opinion predict_cate predict_polarity
# 1422      4     总体     还不错           整体               正面
# 2247      9     质量      很好           整体               正面
# 8153     13     质量     非常好           整体               正面
# 7312     33     质量    不怎么样           整体               负面
# 796      64     质量      很好           整体               正面
# 8094     78     质量     特别好           整体               正面
# 10792    84     质量      很好           整体               正面
# 8057     85     质量     没问题           整体               正面
# 10616   100     质量      不错           整体               正面
# 465     100     质量     挺好的           整体               正面
# 10362   103     质量      很好           整体               正面
# 1134    122     质量      很好           整体               正面
# 10090   128     质量      很好           整体               正面
# 10820   131     质量      很好           整体               正面
# 5342    133     质量      不错           整体               正面
# 8396    138     质量      不错           整体               正面
# 4316    156     质量     非常好           整体               正面
# 2113    160     质量      很好           整体               正面
# 642     173     质量      很好           整体               正面
# 7785    175   整体效果     杠杠的           整体               正面
# 274     192     质量      不错           整体               正面
# 2168    204     质量      很好           整体               正面
# 9041    206     质量      很好           整体               正面
# 7096    223     质量      很好           整体               正面
# 6568    229     质量      很好           整体               正面
# 7974    240     质量      不错           整体               正面
# 328     241     功能      齐全           整体               正面
# 1830    248     质量     还不错           整体               正面
# 2483    249     整体       _           整体               正面
# 1564    262     质量      很好           整体               正面
# ...     ...    ...     ...          ...              ...
# 6460   3686     总体    还算可以           整体               正面
# 2804   3688     质量      很好           整体               正面
# 1868   3691     质量      不错           整体               正面
# 2900   3696     质量      不错           整体               正面
# 510    3698     质量      很好           整体               正面
# 1468   3712     质量      不错           整体               正面
# 10374  3722     质量      不错           整体               正面
# 7138   3723     质量      很好           整体               正面
# 7840   3726     质量      很好           整体               正面
# 897    3728     质量      很好           整体               正面
# 2111   3744     质量      很好           整体               正面
# 1381   3750     质量      很好           整体               正面
# 6126   3773     质量      很好           整体               正面
# 1239   3776     质量     很不错           整体               正面
# 5467   3778     质量     还可以           整体               正面
# 9656   3791     质量     特别好           整体               正面
# 7845   3793     质量      不错           整体               正面
# 5749   3802     质量       好           整体               正面
# 70     3810     质量      很好           整体               正面
# 9275   3829     质量     挺好的           整体               正面
# 3451   3840     质量      不错           整体               正面
# 3052   3843     质量      很好           整体               正面
# 1512   3861     质量      很好           整体               正面
# 10838  3864     质量      不错           整体               正面
# 10093  3867     质量      不错           整体               正面
# 5112   3868     质量      很好           整体               正面
# 4031   3870     质量      很好           整体               正面
# 5374   3875     质量       _           整体               正面
# 3588   3877     质量     非常好           整体               正面
# 8365   3886     质量      不错           整体               正面
#
# [511 rows x 5 columns]

# %%
sort_submit = submit.sort_values(by=['id','aspect','opinion'])

# %%
a = submit.groupby('id')['predict_polarity'].apply(list)

# %%
sort_submit['new_polar']= old.sort_values(by=[0,1,2])[4]

# %%
sort_submit[sort_submit.new_polar!=sort_submit.predict_polarity]
# Out:
#          id aspect   opinion predict_cate predict_polarity new_polar
# 4383      3      _       有点卡        硬件&性能               负面        正面
# 11218     3      _       有点慢        硬件&性能               负面        正面
# 1565      5     外观        好看           外观               正面        负面
# 9865      6     包装      特别严实           包装               正面        负面
# 11110     7     学习       用得上         使用场景               正面        负面
# 5315      9      _      非常满意           整体               正面        负面
# 2514     10      _       很喜欢           整体               正面        负面
# 4680     10     外观      挺好看的           外观               正面        负面
# 5811     10     系统       挺流畅        软件&性能               正面        负面
# 5410     13   显卡速度         快        硬件&性能               正面        负面
# 7011     15      _      还算不错           整体               正面        负面
# 7435     15     速度        不差        硬件&性能               正面        负面
# 2700     17      _       很不错           整体               正面        负面
# 10788    21      _       有点卡        硬件&性能               负面        正面
# 2277     24      _        轻薄           外观               正面        负面
# 0        25      _         _            _                _        正面
# 9235     27     操作        流畅         使用场景               正面        负面
# 8852     30     价格        实惠           价格               正面        负面
# 8788     32      _         厚           外观               负面        正面
# 10948    33     屏幕       有亮点        硬件&性能               负面        正面
# 7312     33     质量      不怎么样           整体               负面        正面
# 10849    34      _        经脏           外观               负面        正面
# 11009    35      _        降价           价格               负面        正面
# 6437     36      _        降价           价格               负面        正面
# 4649     37      _       有杂音        硬件&性能               负面        正面
# 3128     37     内存         _        硬件&性能               负面        正面
# 8435     38      _        可以           整体               正面        负面
# 1018     38      _       很舒服           外观               正面        负面
# 3500     40     外观       挺新的           外观               正面        负面
# 9334     41      _        失望           整体               负面        正面
# ...     ...    ...       ...          ...              ...       ...
# 7572   3890      _      真的垃圾           整体               负面        正面
# 8204   3890     温度       这么高        硬件&性能               负面        正面
# 4878   3890     跑分       这么低        硬件&性能               负面        正面
# 3393   3891      _       超喜欢           整体               正面        负面
# 8236   3892      _       很喜欢           整体               正面        负面
# 1726   3893      _        差评           整体               负面        正面
# 970    3894   键盘手感        很好        硬件&性能               正面        负面
# 5692   3895     散热       太差了        硬件&性能               负面        正面
# 7676   3896     网速         快        硬件&性能               正面        负面
# 2385   3897     包装        很差           包装               负面        正面
# 3377   3897   硬盘温度        过高        硬件&性能               负面        正面
# 7171   3898      _       不能用        硬件&性能               负面        正面
# 2510   3898      _         卡        硬件&性能               负面        正面
# 8256   3899     散热        不行        硬件&性能               负面        正面
# 9393   3900     声音       有点大        硬件&性能               负面        正面
# 759    3900     屏幕     是***的        硬件&性能               负面        正面
# 2994   3900     风扇       有点大        硬件&性能               负面        正面
# 4904   3902     包装         _           包装               负面        正面
# 7971   3902     拖动       有划痕           外观               负面        正面
# 2889   3902     散热        不好        硬件&性能               负面        正面
# 2593   3902     显卡         弱        硬件&性能               负面        正面
# 657    3902     温度        稍高        硬件&性能               负面        正面
# 2519   3902    适配器        发热        硬件&性能               负面        正面
# 7547   3903     玩游       不怕卡         使用场景               正面        负面
# 2430   3903     网速        超快        硬件&性能               正面        负面
# 1675   3904     画面        清晰        硬件&性能               正面        负面
# 9557   3907      _  没有u** 接口        硬件&性能               负面        正面
# 2474   3908     运行        流畅        硬件&性能               正面        负面
# 11180  3909      _      非常满意           整体               正面        负面
# 8609   3911     速度         点        硬件&性能               正面        负面
#
# [3744 rows x 6 columns]

# %%
old.sort_values(by=[0,1,2])
# Out:
#           0     1         2      3   4
# 2         1     _      真的不错     整体  正面
# 4         1    吃鸡        不卡   使用场景  正面
# 3         1    携带        方便     外观  正面
# 0         1    画质        清晰  硬件&性能  正面
# 1         1    网速        很快  硬件&性能  正面
# 5         2    包装        很好     包装  正面
# 6         2  物流速度        很棒     物流  正面
# 10        3     _      挺好看的     外观  正面
# 8         3     _       有点卡  硬件&性能  正面
# 7         3     _       有点慢  硬件&性能  正面
# 9         3     _  没有想象中那么好     整体  正面
# 11        4    总体       还不错     整体  正面
# 12        4  玩这游戏        不卡   使用场景  正面
# 16        5     _      五星好评     整体  正面
# 13        5     _      非常惊喜     整体  正面
# 15        5    外观        好看     外观  正面
# 14        5  开机速度         快  硬件&性能  正面
# 17        5    运行        流畅  硬件&性能  正面
# 21        6     _      特别流畅  硬件&性能  正面
# 22        6    价格      真心不错     价格  正面
# 18        6    包装      特别严实     包装  正面
# 20        6  外观设计       有档次     外观  正面
# 19        6    按键        灵活  硬件&性能  正面
# 25        7     _       很喜欢     整体  正面
# 23        7    反应        挺快  硬件&性能  正面
# 24        7    学习       用得上   使用场景  正面
# 28        8     _      太喜欢了     整体  正面
# 26        8     _       非常好     整体  正面
# 27        8    包裹       很严实     包装  正面
# 29        9     _      非常满意     整体  正面
# ...     ...   ...       ...    ...  ..
# 11453  3902   适配器        发热  硬件&性能  负面
# 11452  3902  风扇声音       有点大  硬件&性能  负面
# 11458  3903     _        不错     整体  正面
# 11459  3903     _      挺满意的     整体  正面
# 11461  3903    玩游       不怕卡   使用场景  正面
# 11460  3903    网速        超快  硬件&性能  正面
# 11467  3904     _       无卡顿  硬件&性能  正面
# 11463  3904  卖家态度        很好     服务  正面
# 11466  3904    外观        满意     外观  正面
# 11464  3904    物流        很快     物流  正面
# 11462  3904    画面        清晰  硬件&性能  正面
# 11465  3904    运行        流畅  硬件&性能  正面
# 11472  3905     _       很满意     整体  正面
# 11469  3905     _        满意     整体  正面
# 11471  3905    画质       很高清  硬件&性能  正面
# 11470  3905    运行       很流畅  硬件&性能  正面
# 11468  3905    颜值         高     外观  正面
# 11473  3906     _        很溜     整体  正面
# 11475  3907     _        可以     整体  正面
# 11474  3907     _  没有u** 接口  硬件&性能  负面
# 11476  3908    材质      精致好看     外观  正面
# 11477  3908    运行        流畅  硬件&性能  正面
# 11479  3909     _      非常满意     整体  正面
# 11478  3909   服务员      专业到位     服务  正面
# 11481  3910     _      物美价廉     价格  正面
# 11480  3910     _       还不错     整体  正面
# 11482  3910    办公        正好   使用场景  正面
# 11484  3911     _       不卡机  硬件&性能  正面
# 11485  3911     _      真心喜欢     整体  正面
# 11483  3911    速度         点  硬件&性能  正面
#
# [11486 rows x 5 columns]

# %%
old = pd.read_csv('submit/Result_0917.csv',header=None)

# %%
old[4].value_counts()
# Out:
# 正面    9201
# 负面    2225
# _       60
# Name: 4, dtype: int64

# %%
submit['predict_polarity'].value_counts()
# Out:
# 正面    9119
# 负面    2228
# 中性      79
# _       60
# Name: predict_polarity, dtype: int64

# %%
b = old.groupby(0)[4].count().to_dict()

# %%
sum(b)
# Out:
# 7649916

# %%
sum(a)
# Out:
# 7649916

# %%
a==b
# Out:
# True

# %%
v = 0
for id in a:
    if a[id]!=b[id]:
        v+=1
        print(submit[submit.id==id])
        print(old[old[0]==id])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-322c328a8b39> in <module>
#       1 v = 0
#       2 for id in a:
# ----> 3     if a[id]!=b[id]:
#       4         v+=1
#       5         print(submit[submit.id==id])
#
# KeyError: 0

# %%
b[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-54af0eb47770> in <module>
# ----> 1 b[0]
#
# KeyError: 0

# %%
v
# Out:
# 0

# %%
# problem
# ner is not good

# %%
cate[cate.id==3792]
# Out:
#              text           pos1            pos2 predict_polarity  \
# 3905  **的价格保护很有缺陷  (3, 4, A, 价格)  (7, 10, O, 价格)               负面
#
#      predict_cate    id aspect opinion
# 3905           价格  3792     价格    很有缺陷

# %%
old.shape
# Out:
# (4745, 5)

# %%
submit.shape
# Out:
# (4748, 5)
