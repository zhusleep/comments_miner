# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('result/analysis.csv',sep='\t',index_col=0)

# %%
result['text'] = result['text'].apply(lambda x:''.join(eval(x)))

# %%
result
# Out:
#                                                   text  \
# 0                                  [CLS]很好，超值，很好用[SEP]
# 1                           [CLS]很好，遮暇功能差一些，总体还不错[SEP]
# 2                    [CLS]包装太随便了，连个包装盒都没有，第一感觉很不好[SEP]
# 3                [CLS]宝贝收到了，产品非常的不好，简直就是个垃圾，我都扔了。[SEP]
# 4            [CLS]活动价很是划算，买一送一共60片才花八十五块，天天用都不心疼啊[SEP]
# 5                       [CLS]使用一段时间才来评价，淡淡的香味，喜欢！[SEP]
# 6                            [CLS]之前买过。用了还不错。继续回购[SEP]
# 7                             [CLS]很润相对好推开。总体还可以。[SEP]
# 8                           [CLS]收到了，当天晚上就用了很不错哦，[SEP]
# 9                          [CLS]做活动时买的，比较划算，也比较好用[SEP]
# 10                                  [CLS]好用不油腻很清爽[SEP]
# 11                          [CLS]气垫水润，还送了一个替换装，很值[SEP]
# 12            [CLS]一直在**买东西，质量值得信赖物流还快，以后还会继续关注的。[SEP]
# 13           [CLS]很好的，以前用别的品牌这个品牌以前用的日霜不错这个也应该不错。[SEP]
# 14   [CLS]上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不...
# 15   [CLS]快递员很好，我当时没在家，给放到物业了，提醒我说，是一个小盒！用着也挺好用，自然真...
# 16                     [CLS]一般般，还可以，价格不算贵！用起来一般般啦[SEP]
# 17   [CLS]一直在用，感觉还是不错，这次还有小礼品，谢谢啦！还有快递小哥，今天下了雪如期送达，...
# 18                 [CLS]一直买在**买一个牌子的面膜，真的很补水，用完还来[SEP]
# 19                                  [CLS]宝贝收到非常喜欢[SEP]
# 20                       [CLS]还不错  物流很快 用了再追评使用感受[SEP]
# 21            [CLS]满满一箱，上百片面膜可以用很久了，发货收到的比下单的多！赞?[SEP]
# 22                      [CLS]用着还可以主要按压比较方便不用倒出来那种[SEP]
# 23                            [CLS]物流很快，商品好。支持**。[SEP]
# 24                           [CLS]太好用了，味道也很好闻，大爱！[SEP]
# 25               [CLS]和实体店买的一样，还送有一个面膜，用了优惠券，太合适了[SEP]
# 26                            [CLS]收到货了物流特别快隔离特别好[SEP]
# 27            [CLS]很好用，一直都买这个牌子的，无限回购，物美价廉，持续囤货中。[SEP]
# 28   [CLS]感觉还好吧，第一次用隔离，一开始操作失误出现点小问题，味道还好，送了卸妆水和面膜都...
# 29   [CLS]已经用了7张，感觉水水嫩嫩的，不过在使用时，每包的乳液有不同，有的多，有的少，总之...
# ..                                                 ...
# 616                    [CLS]~拍的徒手装面膜，都不敢用了，扔柜子里了。[SEP]
# 617                           [CLS]隔离霜不错。用完还会继续买。[SEP]
# 618                            [CLS]性价比比较高，适合学生党。[SEP]
# 619     [CLS]超级难用！！！！上妆超级差，#，。很想退，但是开了封不能退。再#也不买了[SEP]
# 620                               [CLS]多次购买了 挺好用的[SEP]
# 621               [CLS]以前在实体店买过  这次在**买也蛮好的  也不卡粉[SEP]
# 622  [CLS]还没用，但***的产品用了好几种了，都非常的不错，我是敏感肌肤，很适合用这款氨基酸...
# 623                     [CLS]挺不错的  敏感肌终于找到合适的洗面奶了[SEP]
# 624                             [CLS]还不错，隔离效果还可以！[SEP]
# 625                [CLS]昨天用了，挺好的，淡妆卸得干净，量也大，性价比不错[SEP]
# 626        [CLS]宝贝收到了，我要投诉快递员，服务态度不好，还反说我这个人说话不好听[SEP]
# 627                   [CLS]好用 颜色是紫色 偏黄肤色用的显白 用完再来[SEP]
# 628                              [CLS]感觉有点干，不好涂开吧[SEP]
# 629                      [CLS]包装有点失望，都不敢用，试试效果还可以[SEP]
# 630                      [CLS]效果很好，不卡粉，挺划算的，感觉美美哒[SEP]
# 631                     [CLS]还不错，不是那么白，不影响再上一层cc霜[SEP]
# 632                                    [CLS]非常满意。[SEP]
# 633                                 [CLS]买了好几次了喜欢[SEP]
# 634  [CLS]用啦一片还行吧补水我之前有买过这个牌子的面膜好像和这个不太一样！用用看吧不行的话换...
# 635                              [CLS]服务不好还叫我发5颗星[SEP]
# 636         [CLS]包装精美，物流还是一如既往的快，还没用过这个面膜，用过了再来评价[SEP]
# 637                       [CLS]一直听说很好用就买了，试了试觉得不错[SEP]
# 638             [CLS]宝贝收到，还没用，双十二买的便宜备用的，老顾客了，挺满意[SEP]
# 639  [CLS]今天才收到，跟在实体店买的一样，买了三瓶送了好几样赠品，用了效果好以后护肤品就在你...
# 640                        [CLS]面膜很好，女儿看着说我也要用，哈哈[SEP]
# 641                 [CLS]还可以吧，不是那么水润，味道有点大，物流挺快的。[SEP]
# 642                  [CLS]一直在用，感觉隔离效果不错，绿色显得皮肤很白。[SEP]
# 643                                 [CLS]酒精味道比较浓郁[SEP]
# 644                       [CLS]不错，很好用，能遮暇，自然美，很喜欢[SEP]
# 645                               [CLS]还不错，我用了很久了[SEP]
#
#                                                   pred  \
# 0                   ['很好', 'O', '超值', 'O', '很好用', 'O']
# 1     ['很好', 'O', '遮暇功能', 'A', '差一些', 'O', '还不错', 'O']
# 2    ['包装', 'A', '太随便了', 'O', '包装盒', 'A', '没有', 'O'...
# 3                                       ['非常的不好', 'O']
# 4                                        ['很是划算', 'O']
# 5                   ['淡淡的', 'O', '香味', 'A', '喜欢', 'O']
# 6                                         ['还不错', 'O']
# 7                  ['很润', 'O', '好推开', 'O', '还可以', 'O']
# 8                                         ['很不错', 'O']
# 9                ['活动', 'A', '比较划算', 'O', '比较好用', 'O']
# 10                 ['好用', 'O', '不油腻', 'O', '很清爽', 'O']
# 11                              ['水润', 'O', '很值', 'O']
# 12                               ['物流', 'A', '快', 'O']
# 13                                         ['很好', 'O']
# 14              ['容易上妆', 'O', '有点出油', 'O', '还不错', 'O']
# 15    ['快递员', 'A', '很好', 'O', '挺好用', 'O', '自然真实', 'O']
# 16   ['一般般', 'O', '还可以', 'O', '价格', 'A', '不算贵', 'O'...
# 17                            ['不错', 'O', '快递小哥', 'A']
# 18                                        ['很补水', 'O']
# 19                                       ['非常喜欢', 'O']
# 20                  ['还不错', 'O', '物流', 'A', '很快', 'O']
# 21                                                  []
# 22                           ['还可以', 'O', '比较方便', 'O']
# 23                    ['物流', 'A', '很快', 'O', '好', 'O']
# 24     ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']
# 25                                       ['太合适了', 'O']
# 26      ['物流', 'A', '特别快', 'O', '隔离', 'A', '特别好', 'O']
# 27                           ['很好用', 'O', '物美价廉', 'O']
# 28                 ['还好', 'O', '味道', 'A', '挺好用的', 'O']
# 29                                      ['水水嫩嫩的', 'O']
# ..                                                 ...
# 616                                                 []
# 617                                        ['不错', 'O']
# 618                           ['性价比', 'A', '比较高', 'O']
# 619               ['超级难用', 'O', '上妆', 'A', '超级差', 'O']
# 620                                      ['挺好用的', 'O']
# 621                           ['蛮好的', 'O', '不卡粉', 'O']
# 622                                     ['非常的不错', 'O']
# 623                                      ['挺不错的', 'O']
# 624              ['还不错', 'O', '隔离效果', 'A', '还可以', 'O']
# 625  ['挺好的', 'O', '卸得干净', 'O', '量也大', 'O', '性价比', '...
# 626               ['快递员', 'A', '服务态度', 'A', '不好', 'O']
# 627                             ['好用', 'O', '显白', 'O']
# 628                          ['有点干', 'O', '不好涂开', 'O']
# 629               ['包装', 'A', '有点失望', 'O', '还可以', 'O']
# 630   ['很好', 'O', '不卡粉', 'O', '挺划算的', 'O', '美美哒', 'O']
# 631                         ['还不错', 'O', '不是那么白', 'O']
# 632                                      ['非常满意', 'O']
# 633                                        ['喜欢', 'O']
# 634                                        ['还行', 'O']
# 635                             ['服务', 'A', '不好', 'O']
# 636   ['包装', 'A', '精美', 'O', '物流', 'A', '一如既往的快', 'O']
# 637                            ['很好用', 'O', '不错', 'O']
# 638                                       ['挺满意', 'O']
# 639                                        ['赠品', 'A']
# 640                                        ['很好', 'O']
# 641  ['还可以', 'O', '不是那么水润', 'O', '味道', 'A', '有点大', ...
# 642                ['隔离效果', 'A', '不错', 'O', '很白', 'O']
# 643                         ['酒精味道', 'A', '比较浓郁', 'O']
# 644  ['不错', 'O', '很好用', 'O', '能遮暇', 'O', '自然美', 'O'...
# 645                                       ['还不错', 'O']
#
#                                                  label
# 0                   ['很好', 'O', '超值', 'O', '很好用', 'O']
# 1     ['很好', 'O', '遮暇功能', 'A', '差一些', 'O', '还不错', 'O']
# 2    ['包装', 'A', '太随便了', 'O', '包装盒', 'A', '没有', 'O'...
# 3                            ['非常的不好', 'O', '垃圾', 'O']
# 4                                        ['很是划算', 'O']
# 5                   ['淡淡的', 'O', '香味', 'A', '喜欢', 'O']
# 6                                         ['还不错', 'O']
# 7                  ['很润', 'O', '好推开', 'O', '还可以', 'O']
# 8                                         ['很不错', 'O']
# 9                           ['比较划算', 'O', '比较好用', 'O']
# 10                 ['好用', 'O', '不油腻', 'O', '很清爽', 'O']
# 11                              ['水润', 'O', '很值', 'O']
# 12                               ['物流', 'A', '快', 'O']
# 13                             ['很好的', 'O', '不错', 'O']
# 14   ['上妆效果', 'A', '容易上妆', 'O', '持久情况', 'A', '还不错',...
# 15   ['快递员', 'A', '很好', 'O', '挺好用', 'O', '自然', 'O',...
# 16     ['一般般', 'O', '还可以', 'O', '价格', 'A', '不算贵', 'O']
# 17                ['不错', 'O', '小礼品', 'A', '快递小哥', 'A']
# 18                                        ['很补水', 'O']
# 19                                       ['非常喜欢', 'O']
# 20                  ['还不错', 'O', '物流', 'A', '很快', 'O']
# 21                                          ['赞', 'O']
# 22                           ['还可以', 'O', '比较方便', 'O']
# 23                    ['物流', 'A', '很快', 'O', '好', 'O']
# 24     ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']
# 25                            ['优惠券', 'A', '太合适', 'O']
# 26      ['物流', 'A', '特别快', 'O', '隔离', 'A', '特别好', 'O']
# 27                           ['很好用', 'O', '物美价廉', 'O']
# 28     ['还好吧', 'O', '味道', 'A', '还好', 'O', '挺好用的', 'O']
# 29                           ['水水嫩嫩的', 'O', '乳液', 'A']
# ..                                                 ...
# 616                                       ['不敢用', 'O']
# 617                                        ['不错', 'O']
# 618                           ['性价比', 'A', '比较高', 'O']
# 619               ['超级难用', 'O', '上妆', 'A', '超级差', 'O']
# 620                                      ['挺好用的', 'O']
# 621                                       ['不卡粉', 'O']
# 622                            ['不错', 'O', '很适合', 'O']
# 623                                      ['挺不错的', 'O']
# 624              ['还不错', 'O', '隔离效果', 'A', '还可以', 'O']
# 625  ['挺好的', 'O', '卸得干净', 'O', '量也大', 'O', '性价比', '...
# 626    ['投诉', 'O', '快递员', 'A', '服务态度', 'A', '不好', 'O']
# 627                             ['好用', 'O', '显白', 'O']
# 628                          ['有点干', 'O', '不好涂开', 'O']
# 629               ['包装', 'A', '有点失望', 'O', '还可以', 'O']
# 630   ['很好', 'O', '不卡粉', 'O', '挺划算的', 'O', '美美哒', 'O']
# 631                         ['还不错', 'O', '不是那么白', 'O']
# 632                                      ['非常满意', 'O']
# 633                                        ['喜欢', 'O']
# 634                            ['还行吧', 'O', '补水', 'O']
# 635                             ['服务', 'A', '不好', 'O']
# 636        ['包装', 'A', '精美', 'O', '物流', 'A', '快', 'O']
# 637                                        ['不错', 'O']
# 638                            ['便宜', 'O', '挺满意', 'O']
# 639                                        ['赠品', 'A']
# 640                                        ['很好', 'O']
# 641  ['还可以吧', 'O', '不是那么水润', 'O', '味道', 'A', '有点大',...
# 642            ['隔离效果', 'A', '不错', 'O', '显得皮肤很白', 'O']
# 643                         ['酒精味道', 'A', '比较浓郁', 'O']
# 644  ['不错', 'O', '很好用', 'O', '能遮暇', 'O', '自然美', 'O'...
# 645                                       ['还不错', 'O']
#
# [646 rows x 3 columns]

# %%
# sentence splitter
['，','！',' ','?','。','\n','～']

# %%
result['count_m']=result['label'].apply(lambda x:len(eval(x))/2)

# %%
result['count_m'].sum()
# Out:
# 1690.0

# %%
train = pd.read_csv('TRAIN/Train_reviews.csv')
labels = pd.read_csv('TRAIN/Train_labels.csv')

# %%
train
# Out:
#         id                                            Reviews
# 0        1                                          很好，超值，很好用
# 1        2                                   很好，遮暇功能差一些，总体还不错
# 2        3                            包装太随便了，连个包装盒都没有，第一感觉很不好
# 3        4                        宝贝收到了，产品非常的不好，简直就是个垃圾，我都扔了。
# 4        5                    活动价很是划算，买一送一共60片才花八十五块，天天用都不心疼啊
# 5        6                               使用一段时间才来评价，淡淡的香味，喜欢！
# 6        7                                    之前买过。用了还不错。继续回购
# 7        8                                     很润相对好推开。总体还可以。
# 8        9                                   收到了，当天晚上就用了很不错哦，
# 9       10                                  做活动时买的，比较划算，也比较好用
# 10      11                                           好用不油腻很清爽
# 11      12                                   气垫水润，还送了一个替换装，很值
# 12      13                     一直在**买东西，质量值得信赖物流还快，以后还会继续关注的。
# 13      14                    很好的，以前用别的品牌这个品牌以前用的日霜不错这个也应该不错。
# 14      15  上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不错 适合肤...
# 15      16        快递员很好，我当时没在家，给放到物业了，提醒我说，是一个小盒！用着也挺好用，自然真实！
# 16      17                              一般般，还可以，价格不算贵！用起来一般般啦
# 17      18       一直在用，感觉还是不错，这次还有小礼品，谢谢啦！还有快递小哥，今天下了雪如期送达，感谢！
# 18      19                          一直买在**买一个牌子的面膜，真的很补水，用完还来
# 19      20                                           宝贝收到非常喜欢
# 20      21                                还不错  物流很快 用了再追评使用感受
# 21      22                     满满一箱，上百片面膜可以用很久了，发货收到的比下单的多！赞?
# 22      23                               用着还可以主要按压比较方便不用倒出来那种
# 23      24                                     物流很快，商品好。支持**。
# 24      25                                    太好用了，味道也很好闻，大爱！
# 25      26                        和实体店买的一样，还送有一个面膜，用了优惠券，太合适了
# 26      27                                     收到货了物流特别快隔离特别好
# 27      28                     很好用，一直都买这个牌子的，无限回购，物美价廉，持续囤货中。
# 28      29      感觉还好吧，第一次用隔离，一开始操作失误出现点小问题，味道还好，送了卸妆水和面膜都挺好用的
# 29      30     已经用了7张，感觉水水嫩嫩的，不过在使用时，每包的乳液有不同，有的多，有的少，总之，效果OK
# ...    ...                                                ...
# 3199  3200                               还行吧！还挺香的，希望下次我买了不要降价
# 3200  3201                         活动价69元两盒入手，超级服帖，补水效果很好，很喜欢
# 3201  3202                                     发货速度和配送服务还是一流的
# 3202  3203                          一直用的***，感觉还好，不黏不腻。便宜实惠又好洗
# 3203  3204                                   用着不错，不油腻，有赠品。喜欢！
# 3204  3205                                        非常喜欢，送的礼物也好
# 3205  3206                                        闻着味道和专柜的差不多
# 3206  3207                                                一般般
# 3207  3208  这个不值得买，有问题不极时解决，过敏体质不要买，我就过敏了，和他说一值没有反应，只看信息不解决问题
# 3208  3209                    清洁能力：弱 清洗了之后就和没洗一样，洗面奶很稀没有什么质感。
# 3209  3210              收到了，还没用呢～第一次买，应该挺好的～ 快递也很快哦～有需要还会来买的～
# 3210  3211                     用起特别滋润，提亮肤色的效果非常不错，不油腻！个人感觉不错！
# 3211  3212                                宝贝很好很喜欢质量真心不错满意值得购买
# 3212  3213                               针对脸部各种各样的问题的面膜都有 超喜欢
# 3213  3214                     还没用，第一次买这个牌子的，希望不会让我失望，主要是挺实惠的
# 3214  3215                                  挺超值的，补水效果不错，还会来买。
# 3215  3216                                          一直都用这款，很好
# 3216  3217                           一直用***，感觉不错，这次又买了一大堆，囤货！
# 3217  3218                 昨晚打开用的，用着辣脸啊，今早起来一脸的红疙瘩，还痒，怀疑不是正品啊
# 3218  3219                                     不错哦，物美价廉，值得购买。
# 3219  3220                              跟水乳一起买的，很保湿啊，物美价廉，不错的
# 3220  3221                               还没用，看着不错，送了两个替换装，棒棒哒
# 3221  3222                                             还不错 不干
# 3222  3223                                   凑单买的面膜，很好用，买给妈妈的
# 3223  3224                                             感觉还行哦！
# 3224  3225                             ***，大品牌值得信赖，皮肤亮白！服务周到！
# 3225  3226                  之前也有买过，这是并不是第一次购买，应该是之前一样吧，价格挺优惠的
# 3226  3227                      物流很快，包装不错，第一次使用这个牌子，期待&hellip
# 3227  3228              感觉还可以，唯一的遗憾就是面膜放了香精，希望***官方能把香精去掉就完美了
# 3228  3229               这面膜还挺好用的，连续用了两片补水棒棒的，最主要的是蚕丝面料，轻薄透气。
#
# [3229 rows x 2 columns]

# %%
# aspect and opinion是否连续
span = {}
for index,row in labels.iterrows():
    if row['id'] not in span:
        span[row['id']] = [] 
    if row['AspectTerms']!='_' and row['OpinionTerms']!='_':
        if  int(row['A_start'])>int(row['O_start']):
            print(row['id'])
# Out:
# 6
# 95
# 114
# 143
# 150
# 158
# 163
# 192
# 216
# 235
# 239
# 328
# 351
# 354
# 356
# 372
# 439
# 453
# 457
# 457
# 479
# 488
# 556
# 566
# 627
# 662
# 664
# 664
# 667
# 675
# 678
# 900
# 941
# 945
# 959
# 969
# 976
# 1031
# 1033
# 1046
# 1147
# 1184
# 1196
# 1209
# 1248
# 1254
# 1345
# 1401
# 1418
# 1418
# 1428
# 1465
# 1487
# 1489
# 1557
# 1585
# 1586
# 1659
# 1681
# 1727
# 1735
# 1772
# 1786
# 1802
# 1826
# 1873
# 1933
# 1962
# 1994
# 2019
# 2031
# 2035
# 2045
# 2070
# 2092
# 2116
# 2128
# 2133
# 2196
# 2224
# 2288
# 2315
# 2318
# 2318
# 2346
# 2347
# 2382
# 2448
# 2487
# 2488
# 2520
# 2562
# 2639
# 2674
# 2700
# 2701
# 2725
# 2773
# 2884
# 2898
# 2899
# 2918
# 2983
# 3036
# 3060
# 3064
# 3134
# 3137
# 3184

# %%
result = result.reset_index().rename(columns={'index':'id'})

# %%
result
# Out:
#      level_0   id                                               text  \
# 0          0    0                                [CLS]很好，超值，很好用[SEP]
# 1          1    1                         [CLS]很好，遮暇功能差一些，总体还不错[SEP]
# 2          2    2                  [CLS]包装太随便了，连个包装盒都没有，第一感觉很不好[SEP]
# 3          3    3              [CLS]宝贝收到了，产品非常的不好，简直就是个垃圾，我都扔了。[SEP]
# 4          4    4          [CLS]活动价很是划算，买一送一共60片才花八十五块，天天用都不心疼啊[SEP]
# 5          5    5                     [CLS]使用一段时间才来评价，淡淡的香味，喜欢！[SEP]
# 6          6    6                          [CLS]之前买过。用了还不错。继续回购[SEP]
# 7          7    7                           [CLS]很润相对好推开。总体还可以。[SEP]
# 8          8    8                         [CLS]收到了，当天晚上就用了很不错哦，[SEP]
# 9          9    9                        [CLS]做活动时买的，比较划算，也比较好用[SEP]
# 10        10   10                                 [CLS]好用不油腻很清爽[SEP]
# 11        11   11                         [CLS]气垫水润，还送了一个替换装，很值[SEP]
# 12        12   12           [CLS]一直在**买东西，质量值得信赖物流还快，以后还会继续关注的。[SEP]
# 13        13   13          [CLS]很好的，以前用别的品牌这个品牌以前用的日霜不错这个也应该不错。[SEP]
# 14        14   14  [CLS]上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不...
# 15        15   15  [CLS]快递员很好，我当时没在家，给放到物业了，提醒我说，是一个小盒！用着也挺好用，自然真...
# 16        16   16                    [CLS]一般般，还可以，价格不算贵！用起来一般般啦[SEP]
# 17        17   17  [CLS]一直在用，感觉还是不错，这次还有小礼品，谢谢啦！还有快递小哥，今天下了雪如期送达，...
# 18        18   18                [CLS]一直买在**买一个牌子的面膜，真的很补水，用完还来[SEP]
# 19        19   19                                 [CLS]宝贝收到非常喜欢[SEP]
# 20        20   20                      [CLS]还不错  物流很快 用了再追评使用感受[SEP]
# 21        21   21           [CLS]满满一箱，上百片面膜可以用很久了，发货收到的比下单的多！赞?[SEP]
# 22        22   22                     [CLS]用着还可以主要按压比较方便不用倒出来那种[SEP]
# 23        23   23                           [CLS]物流很快，商品好。支持**。[SEP]
# 24        24   24                          [CLS]太好用了，味道也很好闻，大爱！[SEP]
# 25        25   25              [CLS]和实体店买的一样，还送有一个面膜，用了优惠券，太合适了[SEP]
# 26        26   26                           [CLS]收到货了物流特别快隔离特别好[SEP]
# 27        27   27           [CLS]很好用，一直都买这个牌子的，无限回购，物美价廉，持续囤货中。[SEP]
# 28        28   28  [CLS]感觉还好吧，第一次用隔离，一开始操作失误出现点小问题，味道还好，送了卸妆水和面膜都...
# 29        29   29  [CLS]已经用了7张，感觉水水嫩嫩的，不过在使用时，每包的乳液有不同，有的多，有的少，总之...
# ..       ...  ...                                                ...
# 616      616  616                    [CLS]~拍的徒手装面膜，都不敢用了，扔柜子里了。[SEP]
# 617      617  617                           [CLS]隔离霜不错。用完还会继续买。[SEP]
# 618      618  618                            [CLS]性价比比较高，适合学生党。[SEP]
# 619      619  619     [CLS]超级难用！！！！上妆超级差，#，。很想退，但是开了封不能退。再#也不买了[SEP]
# 620      620  620                               [CLS]多次购买了 挺好用的[SEP]
# 621      621  621               [CLS]以前在实体店买过  这次在**买也蛮好的  也不卡粉[SEP]
# 622      622  622  [CLS]还没用，但***的产品用了好几种了，都非常的不错，我是敏感肌肤，很适合用这款氨基酸...
# 623      623  623                     [CLS]挺不错的  敏感肌终于找到合适的洗面奶了[SEP]
# 624      624  624                             [CLS]还不错，隔离效果还可以！[SEP]
# 625      625  625                [CLS]昨天用了，挺好的，淡妆卸得干净，量也大，性价比不错[SEP]
# 626      626  626        [CLS]宝贝收到了，我要投诉快递员，服务态度不好，还反说我这个人说话不好听[SEP]
# 627      627  627                   [CLS]好用 颜色是紫色 偏黄肤色用的显白 用完再来[SEP]
# 628      628  628                              [CLS]感觉有点干，不好涂开吧[SEP]
# 629      629  629                      [CLS]包装有点失望，都不敢用，试试效果还可以[SEP]
# 630      630  630                      [CLS]效果很好，不卡粉，挺划算的，感觉美美哒[SEP]
# 631      631  631                     [CLS]还不错，不是那么白，不影响再上一层cc霜[SEP]
# 632      632  632                                    [CLS]非常满意。[SEP]
# 633      633  633                                 [CLS]买了好几次了喜欢[SEP]
# 634      634  634  [CLS]用啦一片还行吧补水我之前有买过这个牌子的面膜好像和这个不太一样！用用看吧不行的话换...
# 635      635  635                              [CLS]服务不好还叫我发5颗星[SEP]
# 636      636  636         [CLS]包装精美，物流还是一如既往的快，还没用过这个面膜，用过了再来评价[SEP]
# 637      637  637                       [CLS]一直听说很好用就买了，试了试觉得不错[SEP]
# 638      638  638             [CLS]宝贝收到，还没用，双十二买的便宜备用的，老顾客了，挺满意[SEP]
# 639      639  639  [CLS]今天才收到，跟在实体店买的一样，买了三瓶送了好几样赠品，用了效果好以后护肤品就在你...
# 640      640  640                        [CLS]面膜很好，女儿看着说我也要用，哈哈[SEP]
# 641      641  641                 [CLS]还可以吧，不是那么水润，味道有点大，物流挺快的。[SEP]
# 642      642  642                  [CLS]一直在用，感觉隔离效果不错，绿色显得皮肤很白。[SEP]
# 643      643  643                                 [CLS]酒精味道比较浓郁[SEP]
# 644      644  644                       [CLS]不错，很好用，能遮暇，自然美，很喜欢[SEP]
# 645      645  645                               [CLS]还不错，我用了很久了[SEP]
#
#                                                   pred  \
# 0                   ['很好', 'O', '超值', 'O', '很好用', 'O']
# 1                 ['很好', 'O', '遮暇功能', 'A', '还不错', 'O']
# 2       ['包装', 'A', '包装盒', 'A', '没有', 'O', '很不好', 'O']
# 3                            ['非常的不好', 'O', '垃圾', 'O']
# 4                                         ['活动价', 'A']
# 5                              ['淡淡的', 'O', '喜欢', 'O']
# 6                                         ['还不错', 'O']
# 7                  ['很润', 'O', '好推开', 'O', '还可以', 'O']
# 8                                         ['很不错', 'O']
# 9                ['活动', 'A', '比较划算', 'O', '比较好用', 'O']
# 10                             ['好用', 'O', '很清爽', 'O']
# 11                              ['水润', 'O', '很值', 'O']
# 12                               ['物流', 'A', '快', 'O']
# 13                                         ['很好', 'O']
# 14   ['上妆效果', 'A', '容易上妆', 'O', '持久情况', 'A', '有点出油'...
# 15                 ['快递员', 'A', '挺好用', 'O', '自然', 'O']
# 16     ['一般般', 'O', '还可以', 'O', '价格', 'A', '一般般', 'O']
# 17              ['还是不错', 'O', '小礼品', 'A', '快递小哥', 'A']
# 18                                        ['很补水', 'O']
# 19                                       ['非常喜欢', 'O']
# 20                             ['还不错', 'O', '物流', 'A']
# 21                                         ['发货', 'A']
# 22                           ['还可以', 'O', '比较方便', 'O']
# 23                               ['物流', 'A', '好', 'O']
# 24     ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']
# 25                           ['优惠券', 'A', '太合适了', 'O']
# 26                              ['物流', 'A', '隔离', 'A']
# 27                           ['很好用', 'O', '物美价廉', 'O']
# 28                 ['还好', 'O', '味道', 'A', '挺好用的', 'O']
# 29                                      ['水水嫩嫩的', 'O']
# ..                                                 ...
# 616                                                 []
# 617                                        ['不错', 'O']
# 618                                       ['性价比', 'A']
# 619                           ['超级难用', 'O', '上妆', 'A']
# 620                                      ['挺好用的', 'O']
# 621                           ['蛮好的', 'O', '不卡粉', 'O']
# 622                                     ['非常的不错', 'O']
# 623                                      ['挺不错的', 'O']
# 624                          ['还不错', 'O', '隔离效果', 'A']
# 625      ['挺好的', 'O', '干净', 'O', '量', 'O', '性价比', 'A']
# 626               ['快递员', 'A', '服务态度', 'A', '不好', 'O']
# 627                             ['好用', 'O', '显白', 'O']
# 628                          ['有点干', 'O', '不好涂开', 'O']
# 629                            ['包装', 'A', '还可以', 'O']
# 630   ['很好', 'O', '不卡粉', 'O', '挺划算的', 'O', '美美哒', 'O']
# 631                         ['还不错', 'O', '不是那么白', 'O']
# 632                                      ['非常满意', 'O']
# 633                                        ['喜欢', 'O']
# 634                             ['还行', 'O', '补水', 'O']
# 635                                        ['服务', 'A']
# 636              ['包装', 'A', '物流', 'A', '一如既往的快', 'O']
# 637                            ['很好用', 'O', '不错', 'O']
# 638                            ['便宜', 'O', '挺满意', 'O']
# 639                                        ['赠品', 'A']
# 640                                        ['很好', 'O']
# 641  ['还可以', 'O', '不是那么水润', 'O', '味道', 'A', '物流', 'A']
# 642                           ['隔离效果', 'A', '很白', 'O']
# 643                                      ['酒精味道', 'A']
# 644  ['不错', 'O', '很好用', 'O', '能遮暇', 'O', '自然美', 'O'...
# 645                                       ['还不错', 'O']
#
#                                                  label  count_m
# 0                   ['很好', 'O', '超值', 'O', '很好用', 'O']      3.0
# 1                 ['很好', 'O', '遮暇功能', 'A', '还不错', 'O']      3.0
# 2       ['包装', 'A', '包装盒', 'A', '没有', 'O', '很不好', 'O']      4.0
# 3                            ['非常的不好', 'O', '垃圾', 'O']      2.0
# 4                                        ['很是划算', 'O']      1.0
# 5                              ['淡淡的', 'O', '喜欢', 'O']      2.0
# 6                                         ['还不错', 'O']      1.0
# 7                  ['很润', 'O', '好推开', 'O', '还可以', 'O']      3.0
# 8                                         ['很不错', 'O']      1.0
# 9                           ['比较划算', 'O', '比较好用', 'O']      2.0
# 10                             ['好用', 'O', '很清爽', 'O']      2.0
# 11                              ['水润', 'O', '很值', 'O']      2.0
# 12                               ['物流', 'A', '快', 'O']      2.0
# 13                             ['很好的', 'O', '不错', 'O']      2.0
# 14   ['上妆效果', 'A', '容易上妆', 'O', '持久情况', 'A', '还不错',...      4.0
# 15                 ['快递员', 'A', '挺好用', 'O', '自然', 'O']      3.0
# 16                 ['一般般', 'O', '还可以', 'O', '价格', 'A']      3.0
# 17                ['不错', 'O', '小礼品', 'A', '快递小哥', 'A']      3.0
# 18                                        ['很补水', 'O']      1.0
# 19                                       ['非常喜欢', 'O']      1.0
# 20                             ['还不错', 'O', '物流', 'A']      2.0
# 21                                          ['赞', 'O']      1.0
# 22                           ['还可以', 'O', '比较方便', 'O']      2.0
# 23                               ['物流', 'A', '好', 'O']      2.0
# 24     ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']      4.0
# 25                            ['优惠券', 'A', '太合适', 'O']      2.0
# 26                              ['物流', 'A', '隔离', 'A']      2.0
# 27                           ['很好用', 'O', '物美价廉', 'O']      2.0
# 28                ['还好吧', 'O', '味道', 'A', '挺好用的', 'O']      3.0
# 29                           ['水水嫩嫩的', 'O', '乳液', 'A']      2.0
# ..                                                 ...      ...
# 616                                       ['不敢用', 'O']      1.0
# 617                                        ['不错', 'O']      1.0
# 618                                       ['性价比', 'A']      1.0
# 619                           ['超级难用', 'O', '上妆', 'A']      2.0
# 620                                      ['挺好用的', 'O']      1.0
# 621                                       ['不卡粉', 'O']      1.0
# 622                            ['不错', 'O', '很适合', 'O']      2.0
# 623                                      ['挺不错的', 'O']      1.0
# 624                          ['还不错', 'O', '隔离效果', 'A']      2.0
# 625  ['挺好的', 'O', '卸得干净', 'O', '量也大', 'O', '性价比', 'A']      4.0
# 626                           ['投诉', 'O', '服务态度', 'A']      2.0
# 627                             ['好用', 'O', '显白', 'O']      2.0
# 628                          ['有点干', 'O', '不好涂开', 'O']      2.0
# 629                            ['包装', 'A', '还可以', 'O']      2.0
# 630   ['很好', 'O', '不卡粉', 'O', '挺划算的', 'O', '美美哒', 'O']      4.0
# 631                         ['还不错', 'O', '不是那么白', 'O']      2.0
# 632                                      ['非常满意', 'O']      1.0
# 633                                        ['喜欢', 'O']      1.0
# 634                                       ['还行吧', 'O']      1.0
# 635                                        ['服务', 'A']      1.0
# 636                   ['包装', 'A', '物流', 'A', '快', 'O']      3.0
# 637                                        ['不错', 'O']      1.0
# 638                            ['便宜', 'O', '挺满意', 'O']      2.0
# 639                                        ['赠品', 'A']      1.0
# 640                                        ['很好', 'O']      1.0
# 641  ['还可以吧', 'O', '不是那么水润', 'O', '味道', 'A', '物流', ...      4.0
# 642                       ['隔离效果', 'A', '显得皮肤很白', 'O']      2.0
# 643                                      ['酒精味道', 'A']      1.0
# 644  ['不错', 'O', '很好用', 'O', '能遮暇', 'O', '自然美', 'O'...      5.0
# 645                                       ['还不错', 'O']      1.0
#
# [646 rows x 6 columns]

# %%
result['span'] = result.apply(lambda x:span[x.id+1],axis=1)

# %%
data = pd.read_pickle('result/ner_bert_result.pkl')

# %%
train[train.id==502]['Reviews'].values[0][7:9]
# Out:
# '水分'

# %%
labels[labels.id==941]
# Out:
#        id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 1930  941           _                        很好用       0     3         整体
# 1931  941          补水       9    11          很好用       0     3         功效
# 1932  941           _                         便宜      15    17         价格
# 1933  941           _                         优惠      17    19         价格
#
#      Polarities
# 1930         正面
# 1931         正面
# 1932         正面
# 1933         正面

# %%
for index,row in train.iterrows():
    if '很好用，买了很多，补水很好用' in row['Reviews']:
        print(index,row['Reviews'])
# Out:
# 940 很好用，买了很多，补水很好用，便宜优惠

# %%
len('  ')
# Out:
# 2

# %%
'  '=='  '
# Out:
# True

# %%
train[train.Reviews=='味道淡淡的 水分超足 没有刺激感']
# Out:
# Empty DataFrame
# Columns: [id, Reviews]
# Index: []

# %%
labels[labels.id==20]
# Out:
#     id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 43  20           _                       非常喜欢       4     8         整体
#
#    Polarities
# 43         正面

# %%
1690*5
# Out:
# 8450
