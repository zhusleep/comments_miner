# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('result/analysis.csv',sep='\t',index_col=0)

# %%
result['text'] = result['text'].apply(lambda x:''.join(eval(x)))

# %%
result[result.pred!=result.label]
# Out:
#                                                   text  \
# 2                                    [CLS]弄文件时会卡顿[SEP]
# 3          [CLS]只一个纸箱包裹，电脑用着还不错，就是**差评，价格乱跳，一天一个价[SEP]
# 4                                [CLS]一切OK，LOL走一走[SEP]
# 6    [CLS]看视频有时候会出现滋滋的卡带现象，这是今天的现象&mdash;&mdash;差不多...
# 7                         [CLS]屏幕不行 买了才7天就各种糊。醉了。[SEP]
# 12                          [CLS]刚买就降价，不太开心，，就这样吧[SEP]
# 16   [CLS]才一个多星期，不想多说什么，有点小卡，音响从刚刚到就一直很烂，声音总是一卡一卡的，...
# 18                     [CLS]电脑已收到，性能很好，又薄，运行很快，满分[SEP]
# 21                        [CLS]质量可以，性价比高，用着很流畅不卡顿[SEP]
# 22        [CLS]买完就降价申请价格保护还不行，反应之后也不处理，反正买完之后各种不爽[SEP]
# 24                                   [CLS]总体很满意的，[SEP]
# 25          [CLS]性能稳定！运行速度快，外观时尚！面板高大上！放在办公室觉得抢眼！[SEP]
# 27   [CLS]马马虎虎，散热不咋地，CPU温度太高，随便打开一个程序CPU温度就达到九十多度[SEP]
# 28   [CLS]这次消费是体验最最最差的一次，五月七号购买的，结果现在降价超过10%，这么快的降价...
# 30     [CLS]不带电脑包，鼠标和鼠标垫，从自带应用商店上下载软件特别慢，非常不好的体验！[SEP]
# 33             [CLS]感觉像是翻新的，才用一个月就卡。边边还脱皮了。**太无语了[SEP]
# 34   [CLS]**物流值得给五星，机子也不错，就是这包装，一裸机这样放里面？好歹也是3000多块...
# 35     [CLS]很好，颜值很高，物流也很快，客服威震天态度和效率都不错。正在尝试玩游戏如何[SEP]
# 37                              [CLS]用了几天，外壳一直有静电[SEP]
# 41                      [CLS]收到有几天了，开机很快，运行也不错的，值[SEP]
# 43                           [CLS]其他挺好，就是字体显示有点模糊[SEP]
# 44              [CLS]这款电脑屏幕清晰，质量又好不比实体店的差，这次购物很满意[SEP]
# 46                         [CLS]还不知道好不好用，但是包装真的是差[SEP]
# 47                                         [CLS]卡[SEP]
# 50         [CLS]很不错呀～这个价格真心不错～物美价廉，是正品呢！办公游戏都不错呀～[SEP]
# 51                                       [CLS]好好好[SEP]
# 52   [CLS]属于自己的第一个本本轻薄这个大小很轻了携带还算方便毕竟新手问了客服好多问题都有耐心...
# 54            [CLS]电脑会莫名死机，卡顿严重，不建议购买。想入手者慎重考虑！！！[SEP]
# 58        [CLS]电脑外观不错，但就唯一不好的是电脑充电发热的厉害而且风扇散热慢还大声[SEP]
# 60                      [CLS]开机关机很快，开PPT慢一点，其他还不错[SEP]
# ..                                                 ...
# 115  [CLS]真是不想说了，音质连我1千多的手机好，听一首歌没有一句话不带杂音的，戴上耳机你会让...
# 118  [CLS]笔记本轻薄小巧，方便携带，整体配置还不错，显示屏清晰盈亮，用来办公商务绰绰有余，玩...
# 119                     [CLS]很满意 电脑还不错 很喜欢 又很多小功能[SEP]
# 122    [CLS]感谢售后的耐心解答，掌柜还送了很实用的东西，电脑用着很流畅，以后还会光顾，[SEP]
# 123  [CLS]差评好吧，电脑第一天拿到手，两处松动，让我去网点检测，我是服了，新买的电脑检测什么...
# 125          [CLS]入手需要谨慎，~已经有4999的了，5299买几天就降了300[SEP]
# 126          [CLS]很不安的一款平板，质量好价格实惠，屏幕清晰度非常不错，值得购买[SEP]
# 127  [CLS]收货5天了，包装好几层，精美严实。特意玩了几天，很不错的游戏本，高颜值，高性能，不...
# 129  [CLS]很不错！是我喜欢的大红色了！开机很快，挺轻巧的，用来办公很合适！好评，具体性能后面...
# 131   [CLS]我个人觉得这台电脑最好不要下游戏，因为它的通风系统设在底板下面真的不好散热。[SEP]
# 132          [CLS]还不错，运行很快很稳定，屏幕分辨率高。价格实惠，真的非常满意。[SEP]
# 134                      [CLS]吃鸡极致画质完没运行，就是风扇声音很大[SEP]
# 136               [CLS]**用着一点也不习惯，购买差不多一个月。95新。~我[SEP]
# 137  [CLS]很好 有些问题客服小姐姐和售后小弟弟都给解答  虽然一个小瑕疵 但我就玩玩游戏不影...
# 141                         [CLS]好评，质量挺好的，满意的一次购物[SEP]
# 143                  [CLS]不错不错，物有所值9成新，希望用久点哦。可以的[SEP]
# 146                      [CLS]买给弟弟的，用着挺好，价格比实体店便宜[SEP]
# 147                          [CLS]才买到手就降价300，也是服了[SEP]
# 148                        [CLS]外观超薄好看网速很快不卡，非常满意[SEP]
# 149       [CLS]用了几天，还挺好用的，开机舒服快运行舒服还行，总体感觉还可以，好评。[SEP]
# 151           [CLS]电脑办公可以，lol有点卡顿，**客服给0分，官方客服给满分[SEP]
# 153            [CLS]这电脑不行！给的接口转换器时灵时不灵！操作感觉一般，不好用[SEP]
# 154       [CLS]电脑性能：很流畅，不卡 显卡效果：很清晰，特别好 还会介绍盆友买的 [SEP]
# 155  [CLS]真是服了，在****上买电子产品，每一次宽容都是失望！鼠标在屏幕上乱动，卡，太卡，...
# 156    [CLS]真垃圾什么都没有大家以后千万不要买纯裸机流畅度严重失衡第二次开机就死机了！[SEP]
# 159  [CLS]宝贝收到了物流很快，质量不错，做工精细，外观高端大气上档次，用起来很顺畅，画画清晰...
# 160  [CLS]新机器，很好的机器，给1颗星是关注了几个月就是不降价，当天收完货隔天就降价，不爽1...
# 163                           [CLS]差差差，卡卡，这电脑~谁倒霉[SEP]
# 164  [CLS]电脑收到了外观很漂亮而且操作很流畅而且客服很有耐心回答我的问题  最棒的是在快递过...
# 172                   [CLS]不怎么样 不到一星期就崩盘 去代理点还要收费[SEP]
#
#                                                   pred  \
# 2                                     ['卡顿', 'EO使用场景']
# 3    ['纸箱', 'EA包装', '包裹', 'EA包装', '还不错', 'EO整体', '差...
# 4                                                   []
# 6                   ['看视频', 'EA使用场景', '卡带', 'EO硬件&性能']
# 7    ['屏幕', 'EA硬件&性能', '不行', 'EO硬件&性能', '各种糊', 'EO整体']
# 12                                      ['降价', 'EO价格']
# 16   ['有点小卡', 'EO硬件&性能', '音响', 'EA硬件&性能', '很烂', 'EO...
# 18   ['性能', 'EA硬件&性能', '很好', 'EO硬件&性能', '又薄', 'EO外观...
# 21   ['质量', 'EA整体', '可以', 'EO整体', '性价比', 'EA价格', '高...
# 22                 ['反应', 'EA硬件&性能', '不处理', 'EO硬件&性能']
# 24                                     ['很满意', 'EO整体']
# 25   ['性能', 'EA硬件&性能', '稳定', 'EO硬件&性能', '运行速度', 'EA...
# 27   ['散热', 'EA硬件&性能', '不咋地', 'EO硬件&性能', 'CPU温度', '...
# 28                        ['降价', 'EO价格', '降价', 'EO价格']
# 30   ['鼠标', 'EA硬件&性能', '下载软件', 'EA使用场景', '特别慢', 'EO...
# 33                                     ['脱皮了', 'EO外观']
# 34          ['物流', 'EA物流', '不错', 'EO整体', '包装', 'EA包装']
# 35   ['很好', 'EO整体', '颜值', 'EA外观', '很高', 'EO外观', '物流...
# 37                       ['外壳', 'EA外观', '有静电', 'EO外观']
# 41   ['开机', 'EA硬件&性能', '很快', 'EO硬件&性能', '运行', 'EA硬件...
# 43   ['挺好', 'EO整体', '字体', 'EA硬件&性能', '有点模糊', 'EO硬件&...
# 44   ['屏幕', 'EA硬件&性能', '清晰', 'EO硬件&性能', '质量', 'EA整体...
# 46      ['好不好用', 'EO整体', '包装', 'EA包装', '真的是差', 'EO包装']
# 47                                     ['卡', 'SO使用场景']
# 50   ['很不错', 'EO整体', '价格', 'EA价格', '真心不错', 'EO价格', ...
# 51                                     ['好好好', 'EO整体']
# 52   ['大小', 'EA外观', '很轻', 'EO外观', '携带', 'EA外观', '算方...
# 54              ['莫名死机', 'EO硬件&性能', '卡顿严重', 'EO硬件&性能']
# 58   ['外观', 'EA外观', '不错', 'EO外观', '发热', 'EA硬件&性能', ...
# 60   ['开机关机', 'EA硬件&性能', '很快', 'EO硬件&性能', '开PPT', '...
# ..                                                 ...
# 115  ['音质', 'EA硬件&性能', '听一首歌', 'EA使用场景', '不带杂音', 'E...
# 118  ['轻薄小巧', 'EO外观', '方便携带', 'EO外观', '配置', 'EA硬件&性...
# 119      ['很满意', 'EO整体', '还不错', 'EO整体', '很喜欢', 'EO整体']
# 122    ['售后', 'EA服务', '很实用', 'EO价格', '很流畅', 'EO硬件&性能']
# 123                  ['差评', 'EO整体', '两处松动', 'EO硬件&性能']
# 125                                     ['降了', 'EO价格']
# 126  ['质量', 'EA整体', '好', 'SO整体', '价格', 'EA价格', '实惠'...
# 127  ['包装', 'EA包装', '好几层', 'EO包装', '精美严实', 'EO包装', ...
# 129  ['很不错', 'EO整体', '开机', 'EA硬件&性能', '很快', 'EO硬件&性...
# 131             ['通风系统', 'EA硬件&性能', '不好散热', 'EO硬件&性能']
# 132  ['还不错', 'EO整体', '运行', 'EA硬件&性能', '很快', 'EO硬件&性...
# 134  ['吃鸡', 'EA使用场景', '画质', 'EA硬件&性能', '完没运行', 'EO硬...
# 136                                 ['一点也不习惯', 'EO整体']
# 137  ['很好', 'EO整体', '客服小姐姐', 'EA服务', '售后小弟弟', 'EA服务...
# 141        ['好评', 'EO整体', '质量', 'EA整体', '挺好的', 'EO整体']
# 143       ['不错', 'EO整体', '物有所值', 'EO价格', '可以', 'EO整体']
# 146         ['挺好', 'EO整体', '价格', 'EA价格', '便宜', 'EO价格']
# 147                                     ['降价', 'EO价格']
# 148  ['外观', 'EA外观', '超薄', 'EO外观', '好看', 'EO外观', '网速...
# 149  ['挺好用的', 'EO整体', '开机', 'EA硬件&性能', '舒服快', 'EO硬件...
# 151  ['办公', 'EA使用场景', '可以', 'EO使用场景', 'lol', 'EA使用场...
# 153  ['不行', 'EO整体', '接口转换器', 'EA硬件&性能', '灵时不灵', 'EO...
# 154  ['性能', 'EA硬件&性能', '很流畅', 'EO硬件&性能', '不卡', 'EO硬...
# 155  ['鼠标', 'EA硬件&性能', '屏幕', 'EA硬件&性能', '乱动', 'EO硬件...
# 156  ['真垃圾', 'EO整体', '流畅度', 'EA硬件&性能', '严重失衡', 'EO硬...
# 159  ['物流', 'EA物流', '很快', 'EO物流', '质量', 'EA整体', '不错...
# 160        ['很好', 'EO整体', '不降价', 'EO价格', '降价', 'EO价格']
# 163                   ['差差差', 'EO整体', '卡卡', 'EO硬件&性能']
# 164  ['外观', 'EA外观', '很漂亮', 'EO外观', '操作', 'EA使用场景', ...
# 172                                  ['崩盘', 'EO硬件&性能']
#
#                                                  label
# 2                                   ['会卡顿', 'EO硬件&性能']
# 3    ['还不错', 'EO整体', '价格', 'EA价格', '乱跳', 'EO价格', '一...
# 4                                       ['OK', 'EO整体']
# 6                 ['看视频', 'EA使用场景', '滋滋的卡带', 'EO使用场景']
# 7                   ['屏幕', 'EA硬件&性能', '不行', 'EO硬件&性能']
# 12                                   ['刚买就降价', 'EO价格']
# 16   ['有点小卡', 'EO硬件&性能', '音响', 'EA硬件&性能', '一直很烂', '...
# 18   ['性能', 'EA硬件&性能', '很好', 'EO硬件&性能', '薄', 'SO外观'...
# 21   ['质量', 'EA整体', '可以', 'EO整体', '性价比', 'EA价格', '高...
# 22   ['买完就降价', 'EO价格', '申请价格保护还不行', 'EO价格', '不处理', ...
# 24                       ['总体', 'EA整体', '很满意', 'EO整体']
# 25   ['性能', 'EA硬件&性能', '稳定', 'EO硬件&性能', '运行速度', 'EA...
# 27   ['马马虎虎', 'EO整体', '散热', 'EA硬件&性能', '不咋地', 'EO硬件...
# 28                                      ['降价', 'EO价格']
# 30               ['下载软件', 'EA软件&性能', '特别慢', 'EO软件&性能']
# 33     ['像是翻新的', 'EO真伪', '卡', 'SO硬件&性能', '脱皮', 'EO外观']
# 34   ['物流', 'EA物流', '值得给五星', 'EO物流', '不错', 'EO整体', ...
# 35   ['很好', 'EO整体', '颜值', 'EA外观', '很高', 'EO外观', '物流...
# 37                     ['外壳', 'EA外观', '一直有静电', 'EO外观']
# 41   ['开机', 'EA硬件&性能', '很快', 'EO硬件&性能', '运行', 'EA硬件...
# 43   ['挺好', 'EO整体', '字体显示', 'EA硬件&性能', '有点模糊', 'EO硬...
# 44   ['屏幕', 'EA硬件&性能', '清晰', 'EO硬件&性能', '质量', 'EA整体...
# 46                      ['包装', 'EA包装', '真的是差', 'EO包装']
# 47                                    ['卡', 'SO硬件&性能']
# 50   ['很不错', 'EO整体', '价格', 'EA价格', '真心不错', 'EO价格', ...
# 51                                       ['好', 'SO整体']
# 52   ['轻薄', 'EO外观', '很轻', 'EO外观', '携带', 'EA外观', '还算...
# 54                ['死机', 'EO硬件&性能', '卡顿严重', 'EO硬件&性能']
# 58   ['外观', 'EA外观', '不错', 'EO外观', '充电', 'EA硬件&性能', ...
# 60   ['开机关机', 'EA硬件&性能', '很快', 'EO硬件&性能', '开PPT', '...
# ..                                                 ...
# 115  ['音质', 'EA硬件&性能', '杂音', 'EO硬件&性能', '差', 'SO服务'...
# 118  ['轻薄小巧', 'EO外观', '方便携带', 'EO外观', '整体配置', 'EA硬件...
# 119  ['很满意', 'EO整体', '还不错', 'EO整体', '很喜欢', 'EO整体', ...
# 122     ['售后', 'EA服务', '耐心', 'EO服务', '很流畅', 'EO硬件&性能']
# 123                      ['差评', 'EO整体', '太差了', 'EO整体']
# 125                                 ['买几天就降了', 'EO价格']
# 126  ['很不安', 'EO整体', '质量', 'EA整体', '好', 'SO整体', '价格...
# 127  ['包装', 'EA包装', '精美严实', 'EO包装', '很不错', 'EO整体', ...
# 129  ['很不错', 'EO整体', '大红色', 'EO外观', '开机', 'EA硬件&性能'...
# 131                              ['真的不好散热', 'EO硬件&性能']
# 132  ['还不错', 'EO整体', '运行', 'EA硬件&性能', '很快', 'EO硬件&性...
# 134  ['吃鸡', 'EA使用场景', '完没运行', 'EO使用场景', '风扇声音', 'EA...
# 136                                  ['不习惯', 'EO使用场景']
# 137  ['很好', 'EO整体', '客服小姐姐', 'EA服务', '售后小弟弟', 'EA服务...
# 141  ['好评', 'EO整体', '质量', 'EA整体', '挺好的', 'EO整体', '满...
# 143  ['不错', 'EO整体', '物有所值', 'EO价格', '9成新', 'EO外观', ...
# 146     ['挺好', 'EO整体', '价格', 'EA价格', '比实体店便宜', 'EO价格']
# 147                                ['才买到手就降价', 'EO价格']
# 148  ['外观', 'EA外观', '超薄好看', 'EO外观', '网速', 'EA硬件&性能'...
# 149  ['挺好用的', 'EO整体', '开机舒服', 'EA硬件&性能', '快', 'SO硬件...
# 151  ['办公', 'EA使用场景', '可以', 'EO使用场景', '有点卡顿', 'EO硬件...
# 153  ['不行', 'EO整体', '接口转换器', 'EA硬件&性能', '时灵时不灵', 'E...
# 154  ['性能', 'EA硬件&性能', '很流畅', 'EO硬件&性能', '不卡', 'EO硬...
# 155  ['鼠标', 'EA硬件&性能', '在屏幕上乱动', 'EO硬件&性能', '太卡', '...
# 156  ['真垃圾', 'EO整体', '流畅度', 'EA硬件&性能', '严重失衡', 'EO硬...
# 159  ['物流', 'EA物流', '很快', 'EO物流', '质量', 'EA整体', '不错...
# 160                                  ['隔天就降价', 'EO价格']
# 163                         ['差', 'SO整体', '卡', 'SO整体']
# 164  ['外观', 'EA外观', '很漂亮', 'EO外观', '操作', 'EA使用场景', ...
# 172    ['不怎么样', 'EO整体', '代理点', 'EA服务', '还要收费', 'EO服务']
#
# [88 rows x 3 columns]

# %%
# sentence splitter
['，','！',' ','?','。','\n','～']
# Out:
# ['，', '！', ' ', '?', '。', '\n', '～']

# %%
result['count_m']=result['label'].apply(lambda x:len(eval(x))/2)

# %%
result['count_m'].sum()
# Out:
# 756.0

# %%
train = pd.read_csv('TRAIN/Train_reviews.csv')
labels = pd.read_csv('TRAIN/Train_labels.csv')

# %%
train
# Out:
#         id                                            Reviews
# 0        1                                          很好，超值，很好用
# 1        2                                   很好，遮暇功能差一些，总体还不错
# 2        3                            包装太随便了，连个包装盒都没有，第一感觉很不好
# 3        4                        宝贝收到了，产品非常的不好，简直就是个垃圾，我都扔了。
# 4        5                    活动价很是划算，买一送一共60片才花八十五块，天天用都不心疼啊
# 5        6                               使用一段时间才来评价，淡淡的香味，喜欢！
# 6        7                                    之前买过。用了还不错。继续回购
# 7        8                                     很润相对好推开。总体还可以。
# 8        9                                   收到了，当天晚上就用了很不错哦，
# 9       10                                  做活动时买的，比较划算，也比较好用
# 10      11                                           好用不油腻很清爽
# 11      12                                   气垫水润，还送了一个替换装，很值
# 12      13                     一直在**买东西，质量值得信赖物流还快，以后还会继续关注的。
# 13      14                    很好的，以前用别的品牌这个品牌以前用的日霜不错这个也应该不错。
# 14      15  上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不错 适合肤...
# 15      16        快递员很好，我当时没在家，给放到物业了，提醒我说，是一个小盒！用着也挺好用，自然真实！
# 16      17                              一般般，还可以，价格不算贵！用起来一般般啦
# 17      18       一直在用，感觉还是不错，这次还有小礼品，谢谢啦！还有快递小哥，今天下了雪如期送达，感谢！
# 18      19                          一直买在**买一个牌子的面膜，真的很补水，用完还来
# 19      20                                           宝贝收到非常喜欢
# 20      21                                还不错  物流很快 用了再追评使用感受
# 21      22                     满满一箱，上百片面膜可以用很久了，发货收到的比下单的多！赞?
# 22      23                               用着还可以主要按压比较方便不用倒出来那种
# 23      24                                     物流很快，商品好。支持**。
# 24      25                                    太好用了，味道也很好闻，大爱！
# 25      26                        和实体店买的一样，还送有一个面膜，用了优惠券，太合适了
# 26      27                                     收到货了物流特别快隔离特别好
# 27      28                     很好用，一直都买这个牌子的，无限回购，物美价廉，持续囤货中。
# 28      29      感觉还好吧，第一次用隔离，一开始操作失误出现点小问题，味道还好，送了卸妆水和面膜都挺好用的
# 29      30     已经用了7张，感觉水水嫩嫩的，不过在使用时，每包的乳液有不同，有的多，有的少，总之，效果OK
# ...    ...                                                ...
# 3199  3200                               还行吧！还挺香的，希望下次我买了不要降价
# 3200  3201                         活动价69元两盒入手，超级服帖，补水效果很好，很喜欢
# 3201  3202                                     发货速度和配送服务还是一流的
# 3202  3203                          一直用的***，感觉还好，不黏不腻。便宜实惠又好洗
# 3203  3204                                   用着不错，不油腻，有赠品。喜欢！
# 3204  3205                                        非常喜欢，送的礼物也好
# 3205  3206                                        闻着味道和专柜的差不多
# 3206  3207                                                一般般
# 3207  3208  这个不值得买，有问题不极时解决，过敏体质不要买，我就过敏了，和他说一值没有反应，只看信息不解决问题
# 3208  3209                    清洁能力：弱 清洗了之后就和没洗一样，洗面奶很稀没有什么质感。
# 3209  3210              收到了，还没用呢～第一次买，应该挺好的～ 快递也很快哦～有需要还会来买的～
# 3210  3211                     用起特别滋润，提亮肤色的效果非常不错，不油腻！个人感觉不错！
# 3211  3212                                宝贝很好很喜欢质量真心不错满意值得购买
# 3212  3213                               针对脸部各种各样的问题的面膜都有 超喜欢
# 3213  3214                     还没用，第一次买这个牌子的，希望不会让我失望，主要是挺实惠的
# 3214  3215                                  挺超值的，补水效果不错，还会来买。
# 3215  3216                                          一直都用这款，很好
# 3216  3217                           一直用***，感觉不错，这次又买了一大堆，囤货！
# 3217  3218                 昨晚打开用的，用着辣脸啊，今早起来一脸的红疙瘩，还痒，怀疑不是正品啊
# 3218  3219                                     不错哦，物美价廉，值得购买。
# 3219  3220                              跟水乳一起买的，很保湿啊，物美价廉，不错的
# 3220  3221                               还没用，看着不错，送了两个替换装，棒棒哒
# 3221  3222                                             还不错 不干
# 3222  3223                                   凑单买的面膜，很好用，买给妈妈的
# 3223  3224                                             感觉还行哦！
# 3224  3225                             ***，大品牌值得信赖，皮肤亮白！服务周到！
# 3225  3226                  之前也有买过，这是并不是第一次购买，应该是之前一样吧，价格挺优惠的
# 3226  3227                      物流很快，包装不错，第一次使用这个牌子，期待&hellip
# 3227  3228              感觉还可以，唯一的遗憾就是面膜放了香精，希望***官方能把香精去掉就完美了
# 3228  3229               这面膜还挺好用的，连续用了两片补水棒棒的，最主要的是蚕丝面料，轻薄透气。
#
# [3229 rows x 2 columns]

# %%
# aspect and opinion是否连续
span = {}
for index,row in labels.iterrows():
    if row['id'] not in span:
        span[row['id']] = [] 
    if row['AspectTerms']!='_' and row['OpinionTerms']!='_':
        if  int(row['A_start'])>int(row['O_start']):
            print(row['id'])
# Out:
# 6
# 95
# 114
# 143
# 150
# 158
# 163
# 192
# 216
# 235
# 239
# 328
# 351
# 354
# 356
# 372
# 439
# 453
# 457
# 457
# 479
# 488
# 556
# 566
# 627
# 662
# 664
# 664
# 667
# 675
# 678
# 900
# 941
# 945
# 959
# 969
# 976
# 1031
# 1033
# 1046
# 1147
# 1184
# 1196
# 1209
# 1248
# 1254
# 1345
# 1401
# 1418
# 1418
# 1428
# 1465
# 1487
# 1489
# 1557
# 1585
# 1586
# 1659
# 1681
# 1727
# 1735
# 1772
# 1786
# 1802
# 1826
# 1873
# 1933
# 1962
# 1994
# 2019
# 2031
# 2035
# 2045
# 2070
# 2092
# 2116
# 2128
# 2133
# 2196
# 2224
# 2288
# 2315
# 2318
# 2318
# 2346
# 2347
# 2382
# 2448
# 2487
# 2488
# 2520
# 2562
# 2639
# 2674
# 2700
# 2701
# 2725
# 2773
# 2884
# 2898
# 2899
# 2918
# 2983
# 3036
# 3060
# 3064
# 3134
# 3137
# 3184

# %%
result = result.reset_index().rename(columns={'index':'id'})

# %%
result
# Out:
#       id                                               text  \
# 0      0                              [CLS]显卡效果：比想象中要好[SEP]
# 1      1                [CLS]外观精美，很薄携带方便，玩游戏一点都不卡，很喜欢！[SEP]
# 2      2                                  [CLS]弄文件时会卡顿[SEP]
# 3      3        [CLS]只一个纸箱包裹，电脑用着还不错，就是**差评，价格乱跳，一天一个价[SEP]
# 4      4                              [CLS]一切OK，LOL走一走[SEP]
# 5      5          [CLS]电脑不好用，客服没信用，之前讲好带发票，电脑到后连张收锯都没有[SEP]
# 6      6  [CLS]看视频有时候会出现滋滋的卡带现象，这是今天的现象&mdash;&mdash;差不多...
# 7      7                       [CLS]屏幕不行 买了才7天就各种糊。醉了。[SEP]
# 8      8                          [CLS]电脑价格实惠，速度快，下次还来[SEP]
# 9      9                        [CLS]老公买来玩游戏的，他说速度快，满意[SEP]
# 10    10  [CLS]新机入手，第一次使用**，整体感觉还可以，运行起来声音略大，运行速度感觉不明显，性...
# 11    11                [CLS]很不错，性价比很高，物流快，客服服务态度好，好评。[SEP]
# 12    12                         [CLS]刚买就降价，不太开心，，就这样吧[SEP]
# 13    13                         [CLS]整体来说功能不错哈，**系统好用[SEP]
# 14    14         [CLS]收到宝贝了，款式很好看，电脑配置高，价格实惠，物流也快，给好评！[SEP]
# 15    15                             [CLS]玩游戏一点都不卡，满意。[SEP]
# 16    16  [CLS]才一个多星期，不想多说什么，有点小卡，音响从刚刚到就一直很烂，声音总是一卡一卡的，...
# 17    17             [CLS]收到啦收到啦，包裹很严实，期待***即将带给我的卓越性能[SEP]
# 18    18                    [CLS]电脑已收到，性能很好，又薄，运行很快，满分[SEP]
# 19    19                              [CLS]性能不错，外观挺漂亮的[SEP]
# 20    20                             [CLS]非常好的电脑，非常满意。[SEP]
# 21    21                       [CLS]质量可以，性价比高，用着很流畅不卡顿[SEP]
# 22    22       [CLS]买完就降价申请价格保护还不行，反应之后也不处理，反正买完之后各种不爽[SEP]
# 23    23                               [CLS]刚买第二天就无法开机[SEP]
# 24    24                                  [CLS]总体很满意的，[SEP]
# 25    25         [CLS]性能稳定！运行速度快，外观时尚！面板高大上！放在办公室觉得抢眼！[SEP]
# 26    26          [CLS]收到电脑了 试用了一下 很ok 比较流畅 而且看起来质量也不错[SEP]
# 27    27  [CLS]马马虎虎，散热不咋地，CPU温度太高，随便打开一个程序CPU温度就达到九十多度[SEP]
# 28    28  [CLS]这次消费是体验最最最差的一次，五月七号购买的，结果现在降价超过10%，这么快的降价...
# 29    29                       [CLS]好评。超级漂亮的一款本本，店家也很棒[SEP]
# ..   ...                                                ...
# 143  143                  [CLS]不错不错，物有所值9成新，希望用久点哦。可以的[SEP]
# 144  144                          [CLS]非常实惠，运行流畅，性价比高。[SEP]
# 145  145                          [CLS]电脑手感好棒ヾ ^_^♪好喜欢[SEP]
# 146  146                      [CLS]买给弟弟的，用着挺好，价格比实体店便宜[SEP]
# 147  147                          [CLS]才买到手就降价300，也是服了[SEP]
# 148  148                        [CLS]外观超薄好看网速很快不卡，非常满意[SEP]
# 149  149       [CLS]用了几天，还挺好用的，开机舒服快运行舒服还行，总体感觉还可以，好评。[SEP]
# 150  150          [CLS]产品收到了，画面清晰，网速很看，不卡顿，外观材质也很好，很满意[SEP]
# 151  151           [CLS]电脑办公可以，lol有点卡顿，**客服给0分，官方客服给满分[SEP]
# 152  152         [CLS]运行速度很快玩游戏一点都不卡，显示清晰，音质不错，外观时尚大气！[SEP]
# 153  153            [CLS]这电脑不行！给的接口转换器时灵时不灵！操作感觉一般，不好用[SEP]
# 154  154       [CLS]电脑性能：很流畅，不卡 显卡效果：很清晰，特别好 还会介绍盆友买的 [SEP]
# 155  155  [CLS]真是服了，在****上买电子产品，每一次宽容都是失望！鼠标在屏幕上乱动，卡，太卡，...
# 156  156    [CLS]真垃圾什么都没有大家以后千万不要买纯裸机流畅度严重失衡第二次开机就死机了！[SEP]
# 157  157               [CLS]背面板很薄，塑料感很强，但开机挺快的，继续使用看看吧[SEP]
# 158  158  [CLS]机子很好 外观也很好看的 是正品 值得信赖哦 以后买就买这一家了 东西是真的很好呀...
# 159  159  [CLS]宝贝收到了物流很快，质量不错，做工精细，外观高端大气上档次，用起来很顺畅，画画清晰...
# 160  160  [CLS]新机器，很好的机器，给1颗星是关注了几个月就是不降价，当天收完货隔天就降价，不爽1...
# 161  161                                [CLS]可以，不错值得购买[SEP]
# 162  162                                     [CLS]运营很快[SEP]
# 163  163                           [CLS]差差差，卡卡，这电脑~谁倒霉[SEP]
# 164  164  [CLS]电脑收到了外观很漂亮而且操作很流畅而且客服很有耐心回答我的问题  最棒的是在快递过...
# 165  165                          [CLS]宝贝收到了，很不错，物超所值。[SEP]
# 166  166                               [CLS]刚买不久，降价100[SEP]
# 167  167       [CLS]宝贝收到了，和卖家说的完全吻合，喜欢，大爱，喜欢的亲们可以放心购买。[SEP]
# 168  168                      [CLS]非常满意，真的很喜欢，完全超出期望值。[SEP]
# 169  169          [CLS]摸起来手感非常好，显屏效果非常不错，运行速度很快。推进大家购买[SEP]
# 170  170   [CLS]帮家人买的，外观看起来挺不错，刚开始总的说挺不错的，希望后续也能保持那么好。[SEP]
# 171  171          [CLS]电脑收到了，系统非常流畅，外观也很好看，性价比非常高，非常喜欢[SEP]
# 172  172                   [CLS]不怎么样 不到一星期就崩盘 去代理点还要收费[SEP]
#
#                                                   pred  \
# 0             ['显卡效果', 'EA硬件&性能', '比想象中要好', 'EO硬件&性能']
# 1    ['外观', 'EA外观', '精美', 'EO外观', '很薄', 'EO外观', '携带...
# 2                                     ['卡顿', 'EO使用场景']
# 3    ['纸箱', 'EA包装', '包裹', 'EA包装', '还不错', 'EO整体', '差...
# 4                                                   []
# 5         ['不好用', 'EO整体', '客服', 'EA服务', '没信用', 'EO服务']
# 6                   ['看视频', 'EA使用场景', '卡带', 'EO硬件&性能']
# 7    ['屏幕', 'EA硬件&性能', '不行', 'EO硬件&性能', '各种糊', 'EO整体']
# 8    ['价格', 'EA价格', '实惠', 'EO价格', '速度', 'EA硬件&性能', ...
# 9      ['速度', 'EA硬件&性能', '快', 'SO硬件&性能', '满意', 'EO整体']
# 10   ['还可以', 'EO整体', '声音', 'EA硬件&性能', '略大', 'EO硬件&性...
# 11   ['很不错', 'EO整体', '性价比', 'EA价格', '很高', 'EO价格', '...
# 12                                      ['降价', 'EO价格']
# 13   ['功能', 'EA整体', '不错', 'EO整体', '系统', 'EA软件&性能', ...
# 14   ['款式', 'EA外观', '很好看', 'EO外观', '配置', 'EA硬件&性能',...
# 15   ['玩游戏', 'EA使用场景', '一点都不卡', 'EO使用场景', '满意', 'EO...
# 16   ['有点小卡', 'EO硬件&性能', '音响', 'EA硬件&性能', '很烂', 'EO...
# 17                       ['包裹', 'EA包装', '很严实', 'EO包装']
# 18   ['性能', 'EA硬件&性能', '很好', 'EO硬件&性能', '又薄', 'EO外观...
# 19   ['性能', 'EA硬件&性能', '不错', 'EO硬件&性能', '外观', 'EA外观...
# 20                     ['非常好', 'EO整体', '非常满意', 'EO整体']
# 21   ['质量', 'EA整体', '可以', 'EO整体', '性价比', 'EA价格', '高...
# 22                 ['反应', 'EA硬件&性能', '不处理', 'EO硬件&性能']
# 23                                 ['无法开机', 'EO硬件&性能']
# 24                                     ['很满意', 'EO整体']
# 25   ['性能', 'EA硬件&性能', '稳定', 'EO硬件&性能', '运行速度', 'EA...
# 26   ['很ok', 'EO整体', '比较流畅', 'EO硬件&性能', '质量', 'EA整体...
# 27   ['散热', 'EA硬件&性能', '不咋地', 'EO硬件&性能', 'CPU温度', '...
# 28                        ['降价', 'EO价格', '降价', 'EO价格']
# 29   ['好评', 'EO整体', '超级漂亮', 'EO外观', '店家', 'EA服务', '...
# ..                                                 ...
# 143       ['不错', 'EO整体', '物有所值', 'EO价格', '可以', 'EO整体']
# 144  ['非常实惠', 'EO价格', '运行', 'EA硬件&性能', '流畅', 'EO硬件&...
# 145        ['手感', 'EA外观', '好棒', 'EO外观', '好喜欢', 'EO整体']
# 146         ['挺好', 'EO整体', '价格', 'EA价格', '便宜', 'EO价格']
# 147                                     ['降价', 'EO价格']
# 148  ['外观', 'EA外观', '超薄', 'EO外观', '好看', 'EO外观', '网速...
# 149  ['挺好用的', 'EO整体', '开机', 'EA硬件&性能', '舒服快', 'EO硬件...
# 150  ['画面', 'EA硬件&性能', '清晰', 'EO硬件&性能', '网速', 'EA硬件...
# 151  ['办公', 'EA使用场景', '可以', 'EO使用场景', 'lol', 'EA使用场...
# 152  ['运行速度', 'EA硬件&性能', '很快', 'EO硬件&性能', '玩游戏', 'E...
# 153  ['不行', 'EO整体', '接口转换器', 'EA硬件&性能', '灵时不灵', 'EO...
# 154  ['性能', 'EA硬件&性能', '很流畅', 'EO硬件&性能', '不卡', 'EO硬...
# 155  ['鼠标', 'EA硬件&性能', '屏幕', 'EA硬件&性能', '乱动', 'EO硬件...
# 156  ['真垃圾', 'EO整体', '流畅度', 'EA硬件&性能', '严重失衡', 'EO硬...
# 157  ['背面板', 'EA外观', '很薄', 'EO外观', '塑料感', 'EA外观', '...
# 158  ['很好', 'EO整体', '外观', 'EA外观', '很好看', 'EO外观', '是...
# 159  ['物流', 'EA物流', '很快', 'EO物流', '质量', 'EA整体', '不错...
# 160        ['很好', 'EO整体', '不降价', 'EO价格', '降价', 'EO价格']
# 161                       ['可以', 'EO整体', '不错', 'EO整体']
# 162                 ['运营', 'EA硬件&性能', '很快', 'EO硬件&性能']
# 163                   ['差差差', 'EO整体', '卡卡', 'EO硬件&性能']
# 164  ['外观', 'EA外观', '很漂亮', 'EO外观', '操作', 'EA使用场景', ...
# 165                    ['很不错', 'EO整体', '物超所值', 'EO价格']
# 166                                     ['降价', 'EO价格']
# 167                       ['喜欢', 'EO整体', '大爱', 'EO整体']
# 168                  ['非常满意', 'EO整体', '真的很喜欢', 'EO整体']
# 169  ['手感', 'EA外观', '非常好', 'EO外观', '显屏效果', 'EA硬件&性能...
# 170      ['外观', 'EA外观', '挺不错', 'EO外观', '挺不错的', 'EO整体']
# 171  ['系统', 'EA软件&性能', '非常流畅', 'EO软件&性能', '外观', 'EA...
# 172                                  ['崩盘', 'EO硬件&性能']
#
#                                                  label  count_m
# 0             ['显卡效果', 'EA硬件&性能', '比想象中要好', 'EO硬件&性能']      2.0
# 1    ['外观', 'EA外观', '精美', 'EO外观', '很薄', 'EO外观', '携带...      8.0
# 2                                   ['会卡顿', 'EO硬件&性能']      1.0
# 3    ['还不错', 'EO整体', '价格', 'EA价格', '乱跳', 'EO价格', '一...      4.0
# 4                                       ['OK', 'EO整体']      1.0
# 5         ['不好用', 'EO整体', '客服', 'EA服务', '没信用', 'EO服务']      3.0
# 6                 ['看视频', 'EA使用场景', '滋滋的卡带', 'EO使用场景']      2.0
# 7                   ['屏幕', 'EA硬件&性能', '不行', 'EO硬件&性能']      2.0
# 8    ['价格', 'EA价格', '实惠', 'EO价格', '速度', 'EA硬件&性能', ...      4.0
# 9      ['速度', 'EA硬件&性能', '快', 'SO硬件&性能', '满意', 'EO整体']      3.0
# 10   ['还可以', 'EO整体', '声音', 'EA硬件&性能', '略大', 'EO硬件&性...      7.0
# 11   ['很不错', 'EO整体', '性价比', 'EA价格', '很高', 'EO价格', '...      8.0
# 12                                   ['刚买就降价', 'EO价格']      1.0
# 13   ['功能', 'EA整体', '不错', 'EO整体', '系统', 'EA软件&性能', ...      4.0
# 14   ['款式', 'EA外观', '很好看', 'EO外观', '配置', 'EA硬件&性能',...      9.0
# 15   ['玩游戏', 'EA使用场景', '一点都不卡', 'EO使用场景', '满意', 'EO...      3.0
# 16   ['有点小卡', 'EO硬件&性能', '音响', 'EA硬件&性能', '一直很烂', '...      6.0
# 17                       ['包裹', 'EA包装', '很严实', 'EO包装']      2.0
# 18   ['性能', 'EA硬件&性能', '很好', 'EO硬件&性能', '薄', 'SO外观'...      6.0
# 19   ['性能', 'EA硬件&性能', '不错', 'EO硬件&性能', '外观', 'EA外观...      4.0
# 20                     ['非常好', 'EO整体', '非常满意', 'EO整体']      2.0
# 21   ['质量', 'EA整体', '可以', 'EO整体', '性价比', 'EA价格', '高...      5.0
# 22   ['买完就降价', 'EO价格', '申请价格保护还不行', 'EO价格', '不处理', ...      3.0
# 23                                 ['无法开机', 'EO硬件&性能']      1.0
# 24                       ['总体', 'EA整体', '很满意', 'EO整体']      2.0
# 25   ['性能', 'EA硬件&性能', '稳定', 'EO硬件&性能', '运行速度', 'EA...      9.0
# 26   ['很ok', 'EO整体', '比较流畅', 'EO硬件&性能', '质量', 'EA整体...      4.0
# 27   ['马马虎虎', 'EO整体', '散热', 'EA硬件&性能', '不咋地', 'EO硬件...      5.0
# 28                                      ['降价', 'EO价格']      1.0
# 29   ['好评', 'EO整体', '超级漂亮', 'EO外观', '店家', 'EA服务', '...      4.0
# ..                                                 ...      ...
# 143  ['不错', 'EO整体', '物有所值', 'EO价格', '9成新', 'EO外观', ...      4.0
# 144  ['非常实惠', 'EO价格', '运行', 'EA硬件&性能', '流畅', 'EO硬件&...      5.0
# 145        ['手感', 'EA外观', '好棒', 'EO外观', '好喜欢', 'EO整体']      3.0
# 146     ['挺好', 'EO整体', '价格', 'EA价格', '比实体店便宜', 'EO价格']      3.0
# 147                                ['才买到手就降价', 'EO价格']      1.0
# 148  ['外观', 'EA外观', '超薄好看', 'EO外观', '网速', 'EA硬件&性能'...      5.0
# 149  ['挺好用的', 'EO整体', '开机舒服', 'EA硬件&性能', '快', 'SO硬件...      8.0
# 150  ['画面', 'EA硬件&性能', '清晰', 'EO硬件&性能', '网速', 'EA硬件...      8.0
# 151  ['办公', 'EA使用场景', '可以', 'EO使用场景', '有点卡顿', 'EO硬件...      7.0
# 152  ['运行速度', 'EA硬件&性能', '很快', 'EO硬件&性能', '玩游戏', 'E...     10.0
# 153  ['不行', 'EO整体', '接口转换器', 'EA硬件&性能', '时灵时不灵', 'E...      6.0
# 154  ['性能', 'EA硬件&性能', '很流畅', 'EO硬件&性能', '不卡', 'EO硬...      6.0
# 155  ['鼠标', 'EA硬件&性能', '在屏幕上乱动', 'EO硬件&性能', '太卡', '...      3.0
# 156  ['真垃圾', 'EO整体', '流畅度', 'EA硬件&性能', '严重失衡', 'EO硬...      4.0
# 157  ['背面板', 'EA外观', '很薄', 'EO外观', '塑料感', 'EA外观', '...      6.0
# 158  ['很好', 'EO整体', '外观', 'EA外观', '很好看', 'EO外观', '是...      5.0
# 159  ['物流', 'EA物流', '很快', 'EO物流', '质量', 'EA整体', '不错...     13.0
# 160                                  ['隔天就降价', 'EO价格']      1.0
# 161                       ['可以', 'EO整体', '不错', 'EO整体']      2.0
# 162                 ['运营', 'EA硬件&性能', '很快', 'EO硬件&性能']      2.0
# 163                         ['差', 'SO整体', '卡', 'SO整体']      2.0
# 164  ['外观', 'EA外观', '很漂亮', 'EO外观', '操作', 'EA使用场景', ...      8.0
# 165                    ['很不错', 'EO整体', '物超所值', 'EO价格']      2.0
# 166                                     ['降价', 'EO价格']      1.0
# 167                       ['喜欢', 'EO整体', '大爱', 'EO整体']      2.0
# 168                  ['非常满意', 'EO整体', '真的很喜欢', 'EO整体']      2.0
# 169  ['手感', 'EA外观', '非常好', 'EO外观', '显屏效果', 'EA硬件&性能...      6.0
# 170      ['外观', 'EA外观', '挺不错', 'EO外观', '挺不错的', 'EO整体']      3.0
# 171  ['系统', 'EA软件&性能', '非常流畅', 'EO软件&性能', '外观', 'EA...      7.0
# 172    ['不怎么样', 'EO整体', '代理点', 'EA服务', '还要收费', 'EO服务']      3.0
#
# [173 rows x 5 columns]

# %%
result['span'] = result.apply(lambda x:span[x.id+1],axis=1)

# %%
data = pd.read_pickle('result/ner_bert_result.pkl')

# %%
train[train.id==502]['Reviews'].values[0][7:9]
# Out:
# '水分'

# %%
labels[labels.id==941]
# Out:
#        id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 1930  941           _                        很好用       0     3         整体
# 1931  941          补水       9    11          很好用       0     3         功效
# 1932  941           _                         便宜      15    17         价格
# 1933  941           _                         优惠      17    19         价格
#
#      Polarities
# 1930         正面
# 1931         正面
# 1932         正面
# 1933         正面

# %%
for index,row in train.iterrows():
    if '很好用，买了很多，补水很好用' in row['Reviews']:
        print(index,row['Reviews'])
# Out:
# 940 很好用，买了很多，补水很好用，便宜优惠

# %%
len('  ')
# Out:
# 2

# %%
'  '=='  '
# Out:
# True

# %%
train[train.Reviews=='味道淡淡的 水分超足 没有刺激感']
# Out:
# Empty DataFrame
# Columns: [id, Reviews]
# Index: []

# %%
labels[labels.id==20]
# Out:
#     id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 43  20           _                       非常喜欢       4     8         整体
#
#    Polarities
# 43         正面

# %%
1690*5
# Out:
# 8450
