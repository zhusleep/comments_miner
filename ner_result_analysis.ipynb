# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('result/analysis.csv',sep='\t')

# %%
result['text'] = result['text'].apply(lambda x:''.join(eval(x)))

# %%
result
# Out:
#       Unnamed: 0                                               text  \
# 0              0                                [CLS]很好，超值，很好用[SEP]
# 1              1                         [CLS]很好，遮暇功能差一些，总体还不错[SEP]
# 2              2                  [CLS]包装太随便了，连个包装盒都没有，第一感觉很不好[SEP]
# 3              3              [CLS]宝贝收到了，产品非常的不好，简直就是个垃圾，我都扔了。[SEP]
# 4              4          [CLS]活动价很是划算，买一送一共60片才花八十五块，天天用都不心疼啊[SEP]
# 5              5                     [CLS]使用一段时间才来评价，淡淡的香味，喜欢！[SEP]
# 6              6                          [CLS]之前买过。用了还不错。继续回购[SEP]
# 7              7                           [CLS]很润相对好推开。总体还可以。[SEP]
# 8              8                         [CLS]收到了，当天晚上就用了很不错哦，[SEP]
# 9              9                        [CLS]做活动时买的，比较划算，也比较好用[SEP]
# 10            10                                 [CLS]好用不油腻很清爽[SEP]
# 11            11                         [CLS]气垫水润，还送了一个替换装，很值[SEP]
# 12            12           [CLS]一直在**买东西，质量值得信赖物流还快，以后还会继续关注的。[SEP]
# 13            13          [CLS]很好的，以前用别的品牌这个品牌以前用的日霜不错这个也应该不错。[SEP]
# 14            14  [CLS]上妆效果：容易上妆 个人情况：油性皮肤 持久情况：下午好像有点出油 整体描述：还不...
# 15            15  [CLS]快递员很好，我当时没在家，给放到物业了，提醒我说，是一个小盒！用着也挺好用，自然真...
# 16            16                    [CLS]一般般，还可以，价格不算贵！用起来一般般啦[SEP]
# 17            17  [CLS]一直在用，感觉还是不错，这次还有小礼品，谢谢啦！还有快递小哥，今天下了雪如期送达，...
# 18            18                [CLS]一直买在**买一个牌子的面膜，真的很补水，用完还来[SEP]
# 19            19                                 [CLS]宝贝收到非常喜欢[SEP]
# 20            20                      [CLS]还不错  物流很快 用了再追评使用感受[SEP]
# 21            21           [CLS]满满一箱，上百片面膜可以用很久了，发货收到的比下单的多！赞?[SEP]
# 22            22                     [CLS]用着还可以主要按压比较方便不用倒出来那种[SEP]
# 23            23                           [CLS]物流很快，商品好。支持**。[SEP]
# 24            24                          [CLS]太好用了，味道也很好闻，大爱！[SEP]
# 25            25              [CLS]和实体店买的一样，还送有一个面膜，用了优惠券，太合适了[SEP]
# 26            26                           [CLS]收到货了物流特别快隔离特别好[SEP]
# 27            27           [CLS]很好用，一直都买这个牌子的，无限回购，物美价廉，持续囤货中。[SEP]
# 28            28  [CLS]感觉还好吧，第一次用隔离，一开始操作失误出现点小问题，味道还好，送了卸妆水和面膜都...
# 29            29  [CLS]已经用了7张，感觉水水嫩嫩的，不过在使用时，每包的乳液有不同，有的多，有的少，总之...
# ...          ...                                                ...
# 3199         615                     [CLS]还行吧！还挺香的，希望下次我买了不要降价[SEP]
# 3200         616               [CLS]活动价69元两盒入手，超级服帖，补水效果很好，很喜欢[SEP]
# 3201         617                           [CLS]发货速度和配送服务还是一流的[SEP]
# 3202         618                [CLS]一直用的***，感觉还好，不黏不腻。便宜实惠又好洗[SEP]
# 3203         619                         [CLS]用着不错，不油腻，有赠品。喜欢！[SEP]
# 3204         620                              [CLS]非常喜欢，送的礼物也好[SEP]
# 3205         621                              [CLS]闻着味道和专柜的差不多[SEP]
# 3206         622                                      [CLS]一般般[SEP]
# 3207         623  [CLS]这个不值得买，有问题不极时解决，过敏体质不要买，我就过敏了，和他说一值没有反应，只...
# 3208         624          [CLS]清洁能力：弱 清洗了之后就和没洗一样，洗面奶很稀没有什么质感。[SEP]
# 3209         625    [CLS]收到了，还没用呢～第一次买，应该挺好的～ 快递也很快哦～有需要还会来买的～[SEP]
# 3210         626           [CLS]用起特别滋润，提亮肤色的效果非常不错，不油腻！个人感觉不错！[SEP]
# 3211         627                      [CLS]宝贝很好很喜欢质量真心不错满意值得购买[SEP]
# 3212         628                     [CLS]针对脸部各种各样的问题的面膜都有 超喜欢[SEP]
# 3213         629           [CLS]还没用，第一次买这个牌子的，希望不会让我失望，主要是挺实惠的[SEP]
# 3214         630                        [CLS]挺超值的，补水效果不错，还会来买。[SEP]
# 3215         631                                [CLS]一直都用这款，很好[SEP]
# 3216         632                 [CLS]一直用***，感觉不错，这次又买了一大堆，囤货！[SEP]
# 3217         633       [CLS]昨晚打开用的，用着辣脸啊，今早起来一脸的红疙瘩，还痒，怀疑不是正品啊[SEP]
# 3218         634                           [CLS]不错哦，物美价廉，值得购买。[SEP]
# 3219         635                    [CLS]跟水乳一起买的，很保湿啊，物美价廉，不错的[SEP]
# 3220         636                     [CLS]还没用，看着不错，送了两个替换装，棒棒哒[SEP]
# 3221         637                                   [CLS]还不错 不干[SEP]
# 3222         638                         [CLS]凑单买的面膜，很好用，买给妈妈的[SEP]
# 3223         639                                   [CLS]感觉还行哦！[SEP]
# 3224         640                   [CLS]***，大品牌值得信赖，皮肤亮白！服务周到！[SEP]
# 3225         641        [CLS]之前也有买过，这是并不是第一次购买，应该是之前一样吧，价格挺优惠的[SEP]
# 3226         642            [CLS]物流很快，包装不错，第一次使用这个牌子，期待&hellip[SEP]
# 3227         643    [CLS]感觉还可以，唯一的遗憾就是面膜放了香精，希望***官方能把香精去掉就完美了[SEP]
# 3228         644     [CLS]这面膜还挺好用的，连续用了两片补水棒棒的，最主要的是蚕丝面料，轻薄透气。[SEP]
#
#                                                    pred  \
# 0                    ['很好', 'O', '超值', 'O', '很好用', 'O']
# 1                   ['很好', 'O', '差一些', 'O', '还不错', 'O']
# 2      ['太随便了', 'O', '包装盒', 'A', '没有', 'O', '很不好', 'O']
# 3                             ['非常的不好', 'O', '垃圾', 'O']
# 4                                         ['很是划算', 'O']
# 5                                ['香味', 'A', '喜欢', 'O']
# 6                                          ['还不错', 'O']
# 7                   ['很润', 'O', '好推开', 'O', '还可以', 'O']
# 8                                          ['很不错', 'O']
# 9                 ['活动', 'A', '比较划算', 'O', '比较好用', 'O']
# 10                                         ['很清爽', 'O']
# 11                               ['水润', 'O', '很值', 'O']
# 12                                ['物流', 'A', '快', 'O']
# 13                               ['很好', 'O', '不错', 'O']
# 14    ['上妆效果', 'A', '容易上妆', 'O', '持久情况', 'A', '有点出油'...
# 15                   ['很好', 'O', '挺好用', 'O', '真实', 'O']
# 16     ['一般般', 'O', '还可以', 'O', '不算贵', 'O', '一般般', 'O']
# 17                 ['不错', 'O', '小礼品', 'A', '快递小哥', 'A']
# 18                                         ['很补水', 'O']
# 19                                        ['非常喜欢', 'O']
# 20                              ['还不错', 'O', '很快', 'O']
# 21                                ['发货', 'A', '赞', 'O']
# 22                            ['还可以', 'O', '比较方便', 'O']
# 23                                ['很快', 'O', '好', 'O']
# 24      ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']
# 25                            ['优惠券', 'A', '太合适了', 'O']
# 26                                         ['特别好', 'O']
# 27                            ['很好用', 'O', '物美价廉', 'O']
# 28                 ['还好吧', 'O', '还好', 'O', '挺好用的', 'O']
# 29                                       ['水水嫩嫩的', 'O']
# ...                                                 ...
# 3199                            ['还行', 'O', '挺香的', 'O']
# 3200               ['超级服帖', 'O', '很好', 'O', '很喜欢', 'O']
# 3201             ['发货速度', 'A', '配送服务', 'A', '一流的', 'O']
# 3202     ['还好', 'O', '不黏不腻', 'O', '实惠', 'O', '好洗', 'O']
# 3203      ['不错', 'O', '不油腻', 'O', '赠品', 'A', '喜欢', 'O']
# 3204                 ['非常喜欢', 'O', '礼物', 'A', '好', 'O']
# 3205                            ['味道', 'A', '差不多', 'O']
# 3206                                       ['一般般', 'O']
# 3207                                       ['不值得', 'O']
# 3208                       ['清洁能力', 'A', '没有什么质感', 'O']
# 3209                 ['挺好的', 'O', '快递', 'A', '很快', 'O']
# 3210  ['特别滋润', 'O', '提亮肤色', 'A', '非常不错', 'O', '不油腻',...
# 3211                            ['很喜欢', 'O', '满意', 'O']
# 3212                                       ['超喜欢', 'O']
# 3213                                      ['挺实惠的', 'O']
# 3214                           ['挺超值的', 'O', '不错', 'O']
# 3215                                        ['很好', 'O']
# 3216                                        ['不错', 'O']
# 3217                ['红疙瘩', 'O', '痒', 'O', '不是正品', 'O']
# 3218                          ['不错哦', 'O', '物美价廉', 'O']
# 3219              ['很保湿', 'O', '物美价廉', 'O', '不错的', 'O']
# 3220                            ['不错', 'O', '棒棒哒', 'O']
# 3221                            ['还不错', 'O', '不干', 'O']
# 3222                                       ['很好用', 'O']
# 3223                                        ['还行', 'O']
# 3224                             ['亮白', 'O', '周到', 'O']
# 3225                                      ['挺优惠的', 'O']
# 3226                             ['很快', 'O', '不错', 'O']
# 3227                                       ['还可以', 'O']
# 3228               ['挺好用的', 'O', '棒棒的', 'O', '透气', 'O']
#
#                                                   label
# 0                    ['很好', 'O', '超值', 'O', '很好用', 'O']
# 1                   ['很好', 'O', '差一些', 'O', '还不错', 'O']
# 2      ['太随便了', 'O', '包装盒', 'A', '没有', 'O', '很不好', 'O']
# 3                             ['非常的不好', 'O', '垃圾', 'O']
# 4                                         ['很是划算', 'O']
# 5                                ['香味', 'A', '喜欢', 'O']
# 6                                          ['还不错', 'O']
# 7                   ['很润', 'O', '好推开', 'O', '还可以', 'O']
# 8                                          ['很不错', 'O']
# 9                            ['比较划算', 'O', '比较好用', 'O']
# 10                                         ['很清爽', 'O']
# 11                               ['水润', 'O', '很值', 'O']
# 12                                ['物流', 'A', '快', 'O']
# 13                              ['很好的', 'O', '不错', 'O']
# 14    ['上妆效果', 'A', '容易上妆', 'O', '持久情况', 'A', '还不错',...
# 15                   ['很好', 'O', '挺好用', 'O', '真实', 'O']
# 16                 ['一般般', 'O', '还可以', 'O', '不算贵', 'O']
# 17                 ['不错', 'O', '小礼品', 'A', '快递小哥', 'A']
# 18                                         ['很补水', 'O']
# 19                                        ['非常喜欢', 'O']
# 20                              ['还不错', 'O', '很快', 'O']
# 21                                           ['赞', 'O']
# 22                            ['还可以', 'O', '比较方便', 'O']
# 23                                ['很快', 'O', '好', 'O']
# 24      ['太好用了', 'O', '味道', 'A', '很好闻', 'O', '大爱', 'O']
# 25                             ['优惠券', 'A', '太合适', 'O']
# 26                                         ['特别好', 'O']
# 27                            ['很好用', 'O', '物美价廉', 'O']
# 28                 ['还好吧', 'O', '还好', 'O', '挺好用的', 'O']
# 29                            ['水水嫩嫩的', 'O', '乳液', 'A']
# ...                                                 ...
# 3199                          ['还行吧', 'O', '还挺香的', 'O']
# 3200   ['活动价', 'O', '超级服帖', 'O', '很好', 'O', '很喜欢', 'O']
# 3201             ['发货速度', 'A', '配送服务', 'A', '一流的', 'O']
# 3202   ['还好', 'O', '不黏不腻', 'O', '便宜实惠', 'O', '好洗', 'O']
# 3203      ['不错', 'O', '不油腻', 'O', '赠品', 'A', '喜欢', 'O']
# 3204                                      ['非常喜欢', 'O']
# 3205                            ['味道', 'A', '差不多', 'O']
# 3206                                       ['一般般', 'O']
# 3207                                       ['过敏了', 'O']
# 3208                 ['清洁能力', 'A', '弱', 'O', '很稀', 'O']
# 3209                 ['挺好的', 'O', '快递', 'A', '很快', 'O']
# 3210  ['特别滋润', 'O', '提亮肤色', 'A', '非常不错', 'O', '不油腻',...
# 3211                            ['很喜欢', 'O', '满意', 'O']
# 3212                                       ['超喜欢', 'O']
# 3213                                       ['挺实惠', 'O']
# 3214                           ['挺超值的', 'O', '不错', 'O']
# 3215                                        ['很好', 'O']
# 3216                                        ['不错', 'O']
# 3217                 ['辣脸', 'O', '痒', 'O', '不是正品', 'O']
# 3218                           ['不错', 'O', '物美价廉', 'O']
# 3219               ['很保湿', 'O', '物美价廉', 'O', '不错', 'O']
# 3220                                       ['棒棒哒', 'O']
# 3221                            ['还不错', 'O', '不干', 'O']
# 3222                                       ['很好用', 'O']
# 3223                                        ['还行', 'O']
# 3224                           ['皮肤亮白', 'O', '周到', 'O']
# 3225                                      ['挺优惠的', 'O']
# 3226                             ['很快', 'O', '不错', 'O']
# 3227                            ['还可以', 'O', '香精', 'A']
# 3228  ['挺好用的', 'O', '棒棒的', 'O', '蚕丝面料', 'A', '透气', 'O']
#
# [3229 rows x 4 columns]

# %%
train = pd.read_csv('TRAIN/Train_reviews.csv')
labels = pd.read_csv('TRAIN/Train_labels.csv')

# %%
labels
# Out:
#         id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 0        1           _                         很好       0     2         整体
# 1        1           _                         超值       3     5         价格
# 2        1           _                        很好用       6     9         整体
# 3        2           _                         很好       0     2         整体
# 4        2        遮暇功能       3     7          差一些       7    10         功效
# 5        2           _                        还不错      13    16         整体
# 6        3          包装       0     2         太随便了       2     6         包装
# 7        3         包装盒       9    12           没有      13    15         包装
# 8        3           _                        很不好      20    23         整体
# 9        4           _                      非常的不好       8    13         整体
# 10       4           _                         垃圾      19    21         整体
# 11       5           _                       很是划算       3     7         价格
# 12       6          香味      14    16          淡淡的      11    14         气味
# 13       6           _                         喜欢      17    19         整体
# 14       7           _                        还不错       7    10         整体
# 15       8           _                         很润       0     2       使用体验
# 16       8           _                        好推开       4     7       使用体验
# 17       8           _                        还可以      10    13         整体
# 18       9           _                        很不错      11    14         整体
# 19      10           _                       比较划算       7    11         价格
# 20      10           _                       比较好用      13    17         整体
# 21      11           _                         好用       0     2         整体
# 22      11           _                        不油腻       2     5       使用体验
# 23      11           _                        很清爽       5     8       使用体验
# 24      12           _                         水润       2     4         整体
# 25      12           _                         很值      14    16         价格
# 26      13          物流      15    17            快      18    19         物流
# 27      14           _                        很好的       0     3         整体
# 28      14           _                         不错      28    30         整体
# 29      15        上妆效果       0     4         容易上妆       5     9         功效
# ...    ...         ...     ...   ...          ...     ...   ...        ...
# 6603  3214           _                        挺实惠      26    29         价格
# 6604  3215        补水效果       5     9           不错       9    11         功效
# 6605  3215           _                       挺超值的       0     4         价格
# 6606  3216           _                         很好       7     9         整体
# 6607  3217           _                         不错       9    11         整体
# 6608  3218           _                         辣脸       9    11       使用体验
# 6609  3218           _                          痒      25    26       使用体验
# 6610  3218           _                       不是正品      29    33         真伪
# 6611  3219           _                         不错       0     2         整体
# 6612  3219           _                       物美价廉       4     8         价格
# 6613  3220           _                        很保湿       8    11         功效
# 6614  3220           _                       物美价廉      13    17         价格
# 6615  3220           _                         不错      18    20         整体
# 6616  3221           _                        棒棒哒      17    20         整体
# 6617  3222           _                        还不错       0     3         整体
# 6618  3222           _                         不干       4     6       使用体验
# 6619  3223           _                        很好用       7    10         整体
# 6620  3224           _                         还行       2     4         整体
# 6621  3225           _                       皮肤亮白      12    16         功效
# 6622  3225          服务      17    19           周到      19    21         服务
# 6623  3226          价格      27    29         挺优惠的      29    33         价格
# 6624  3227          物流       0     2           很快       2     4         物流
# 6625  3227          包装       5     7           不错       7     9         包装
# 6626  3228          香精      17    19            _                       成分
# 6627  3228           _                        还可以       2     5         整体
# 6628  3229           _                       挺好用的       4     8         整体
# 6629  3229          补水      15    17          棒棒的      17    20         功效
# 6630  3229        蚕丝面料      26    30            _                       成分
# 6631  3229           _                         轻薄      31    33       使用体验
# 6632  3229           _                         透气      33    35       使用体验
#
#      Polarities
# 0            正面
# 1            正面
# 2            正面
# 3            正面
# 4            负面
# 5            正面
# 6            负面
# 7            负面
# 8            负面
# 9            负面
# 10           负面
# 11           正面
# 12           正面
# 13           正面
# 14           正面
# 15           正面
# 16           正面
# 17           正面
# 18           正面
# 19           正面
# 20           正面
# 21           正面
# 22           正面
# 23           正面
# 24           正面
# 25           正面
# 26           正面
# 27           正面
# 28           正面
# 29           正面
# ...         ...
# 6603         正面
# 6604         正面
# 6605         正面
# 6606         正面
# 6607         正面
# 6608         负面
# 6609         负面
# 6610         负面
# 6611         正面
# 6612         正面
# 6613         正面
# 6614         正面
# 6615         正面
# 6616         正面
# 6617         正面
# 6618         正面
# 6619         正面
# 6620         正面
# 6621         正面
# 6622         正面
# 6623         正面
# 6624         正面
# 6625         正面
# 6626         负面
# 6627         正面
# 6628         正面
# 6629         正面
# 6630         正面
# 6631         正面
# 6632         正面
#
# [6633 rows x 9 columns]

# %%
train[train.Reviews=='发货速度和配送服务还是一流的']
# Out:
#         id         Reviews
# 3201  3202  发货速度和配送服务还是一流的

# %%
labels[labels.id==20]
# Out:
#     id AspectTerms A_start A_end OpinionTerms O_start O_end Categories  \
# 43  20           _                       非常喜欢       4     8         整体
#
#    Polarities
# 43         正面
